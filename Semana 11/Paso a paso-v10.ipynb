# %%
import sys
sys.path.append('./libs')
import util_modelo_final
import importlib

importlib.reload(util_modelo_final)
# probar relu y al final softmax
#bmc bioinformatics
batch_size = [2**10]
epochs = [2**7]
optimizer = ['Adam']
learn_rate = [0.01]
momentum = [0.0]
init_mode = ['uniform']
activation = ['relu']
activation2 = ['relu']
activation_final = ['softmax']
dropout_rate = [0.3]#[0.3, 0.6]
weight_constraint = [2]#[2, 4]
neurons = [10]
hidden_layers = [1]#[4]
hidden_neurons = [10]#[100]
tuned_parameters = [{'keras__batch_size': batch_size, 'keras__epochs': epochs, 'keras__optimizer': optimizer, 'keras__learn_rate': learn_rate, 'keras__momentum': momentum, 'keras__init_mode': init_mode, 'keras__activation': activation, 'keras__activation2': activation2, 'keras__dropout_rate': dropout_rate, 'keras__weight_constraint': weight_constraint, 'keras__neurons': neurons, 'keras__hidden_layers': hidden_layers, 'keras__hidden_neurons': hidden_neurons, 'keras__activation_final': activation_final}]
tesis2 = util_modelo_final.Tesis2(carpeta_base="real",verbose=100,tuned_parameters=tuned_parameters)
# Out:
# Using TensorFlow backend.

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

if (tesis2.verbose > 1): print("*************************************************")
if (tesis2.verbose > 1): print("************ Generando modelo final *************")
if (tesis2.verbose > 1): print("*************************************************")
# %time tesis2.entrenar_modelo_final_keras()
tesis2.modelo_final_generado = True
if (tesis2.verbose > 1):
    print("*************************************************")
    print("************* Mostrando resultados **************")
    print("*************************************************")
    tesis2.mostrar_resultados()
# Out:
# *************************************************
# ************ Generando modelo final *************
# *************************************************
# Fitting 30 folds for each of 1 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-28a80b52f5ad4326a9592620f91fc6e9.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-eddcb3fb7c2948cab100da735f01f4e5.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-2d0be059a4cd4b73ad3ab40d49b1bf92.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-115492ed055143f0aa1bc6ff4b74af33.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-303809a3d262497aad3b1b0244992f5d.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  4.1min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-1af33bb018bf4be3808ceee52bd580a0.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:  4.3min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-8b2fa1701ded42168c5b501bede91858.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:  4.5min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-d2dcc61f71af447fb38d393b7fa6a5b4.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-8d29f6719f6043dea394727eecdc0c41.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:  8.3min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-075dfdc82be246dfabe0a13c5525ee38.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-8b9b8a6223cb4bdb95bbfd3b47e671fd.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:  8.6min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-8ac2bb5ef25c4f43a10862b6d3966ade.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-435cb3cdf61f4fd2ad3f82ae7bce4c35.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed: 13.2min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-48626672bdbc4eefb31151fadcb53cde.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed: 13.4min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-d9246b41d0544cc095897fa032a930d5.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed: 13.6min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-5b725560f6d549c9a9e3eff989f9292a.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-e2932799eae64333a7bf3642a5198692.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed: 17.2min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-2102d0a2fa2a4233930b61fe59128e0f.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed: 17.4min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-deb7b86571d74495848fa4b73d238bc2.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed: 17.6min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed: 17.7min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-02d52d5ec745404290e3c424afc53711.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-5f71af83b98c4aa4851053452d91e532.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 21.2min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-c77673948ada4370ae8c9da95f1918c8.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 21.6min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-ec32439198af4ac0b61ae8d7f4c1c8e8.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 21.7min
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 21.8min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-913be181701546eeb3c200839864c903.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-c812ca56fd5c47e2bf2dce5b65aa9930.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 25.2min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-43c301d366384b24b2fb618c13cf498b.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 25.6min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-bc30387369c448cd88f6a56412e1e68f.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 25.8min
# [Parallel(n_jobs=-1)]: Done  24 out of  30 | elapsed: 25.9min remaining:  6.5min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-09f83f24389e403fb18305e28274899a.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-2884064eab88494d814b5716b7cc52b6.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  25 out of  30 | elapsed: 29.2min remaining:  5.8min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_9628_4333011114/9628-139638563096560-79b87f844d7a4a2bbc1378353e23e794.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  26 out of  30 | elapsed: 29.7min remaining:  4.6min
# [Parallel(n_jobs=-1)]: Done  27 out of  30 | elapsed: 29.9min remaining:  3.3min
# [Parallel(n_jobs=-1)]: Done  28 out of  30 | elapsed: 29.9min remaining:  2.1min
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed: 32.3min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed: 32.3min finished
# WARNING:tensorflow:From /home/jose/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/jose/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/jose/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# CPU times: user 5min 2s, sys: 9 s, total: 5min 11s
# Wall time: 33min 48s
# *************************************************
# ************* Mostrando resultados **************
# *************************************************
# {'mean_fit_time': array([181.63368623]),
#  'std_fit_time': array([19.72305676]),
#  'mean_score_time': array([2.54763854]),
#  'std_score_time': array([0.78938679]),
#  'param_keras__activation': masked_array(data=['relu'],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__activation2': masked_array(data=['relu'],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__activation_final': masked_array(data=['softmax'],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__batch_size': masked_array(data=[1024],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__dropout_rate': masked_array(data=[0.3],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__epochs': masked_array(data=[128],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__hidden_layers': masked_array(data=[1],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__hidden_neurons': masked_array(data=[10],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__init_mode': masked_array(data=['uniform'],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__learn_rate': masked_array(data=[0.01],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__momentum': masked_array(data=[0.0],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__neurons': masked_array(data=[10],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__optimizer': masked_array(data=['Adam'],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__weight_constraint': masked_array(data=[2],
#               mask=[False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'keras__activation': 'relu',
#    'keras__activation2': 'relu',
#    'keras__activation_final': 'softmax',
#    'keras__batch_size': 1024,
#    'keras__dropout_rate': 0.3,
#    'keras__epochs': 128,
#    'keras__hidden_layers': 1,
#    'keras__hidden_neurons': 10,
#    'keras__init_mode': 'uniform',
#    'keras__learn_rate': 0.01,
#    'keras__momentum': 0.0,
#    'keras__neurons': 10,
#    'keras__optimizer': 'Adam',
#    'keras__weight_constraint': 2}],
#  'split0_test_accuracy': array([0.82423039]),
#  'split1_test_accuracy': array([0.8733863]),
#  'split2_test_accuracy': array([0.92068024]),
#  'split3_test_accuracy': array([0.90851539]),
#  'split4_test_accuracy': array([0.85091857]),
#  'split5_test_accuracy': array([0.84347071]),
#  'split6_test_accuracy': array([0.89014399]),
#  'split7_test_accuracy': array([0.80573486]),
#  'split8_test_accuracy': array([0.83962264]),
#  'split9_test_accuracy': array([0.91484608]),
#  'split10_test_accuracy': array([0.915715]),
#  'split11_test_accuracy': array([0.89721946]),
#  'split12_test_accuracy': array([0.92130089]),
#  'split13_test_accuracy': array([0.86705561]),
#  'split14_test_accuracy': array([0.83602284]),
#  'split15_test_accuracy': array([0.86953823]),
#  'split16_test_accuracy': array([0.85153923]),
#  'split17_test_accuracy': array([0.87934459]),
#  'split18_test_accuracy': array([0.88368918]),
#  'split19_test_accuracy': array([0.8857994]),
#  'split20_test_accuracy': array([0.88368918]),
#  'split21_test_accuracy': array([0.90628103]),
#  'split22_test_accuracy': array([0.83788481]),
#  'split23_test_accuracy': array([0.86705561]),
#  'split24_test_accuracy': array([0.85091857]),
#  'split25_test_accuracy': array([0.89883317]),
#  'split26_test_accuracy': array([0.92068024]),
#  'split27_test_accuracy': array([0.87797915]),
#  'split28_test_accuracy': array([0.90379841]),
#  'split29_test_accuracy': array([0.88095829]),
#  'mean_test_accuracy': array([0.87689507]),
#  'std_test_accuracy': array([0.03076493]),
#  'rank_test_accuracy': array([1], dtype=int32),
#  'split0_train_accuracy': array([0.88511026]),
#  'split1_train_accuracy': array([0.88184433]),
#  'split2_train_accuracy': array([0.88166456]),
#  'split3_train_accuracy': array([0.88282882]),
#  'split4_train_accuracy': array([0.88284594]),
#  'split5_train_accuracy': array([0.8819599]),
#  'split6_train_accuracy': array([0.88314557]),
#  'split7_train_accuracy': array([0.88298291]),
#  'split8_train_accuracy': array([0.88411721]),
#  'split9_train_accuracy': array([0.88220816]),
#  'split10_train_accuracy': array([0.88240506]),
#  'split11_train_accuracy': array([0.88366349]),
#  'split12_train_accuracy': array([0.88102678]),
#  'split13_train_accuracy': array([0.88530288]),
#  'split14_train_accuracy': array([0.88111667]),
#  'split15_train_accuracy': array([0.88759288]),
#  'split16_train_accuracy': array([0.88108242]),
#  'split17_train_accuracy': array([0.8795158]),
#  'split18_train_accuracy': array([0.88277317]),
#  'split19_train_accuracy': array([0.88920231]),
#  'split20_train_accuracy': array([0.88076996]),
#  'split21_train_accuracy': array([0.88035904]),
#  'split22_train_accuracy': array([0.88324402]),
#  'split23_train_accuracy': array([0.88340667]),
#  'split24_train_accuracy': array([0.88298291]),
#  'split25_train_accuracy': array([0.8810439]),
#  'split26_train_accuracy': array([0.88007653]),
#  'split27_train_accuracy': array([0.88719481]),
#  'split28_train_accuracy': array([0.88755436]),
#  'split29_train_accuracy': array([0.88197702]),
#  'mean_train_accuracy': array([0.88303328]),
#  'std_train_accuracy': array([0.00233432]),
#  'split0_test_precision': array([0.75708661]),
#  'split1_test_precision': array([0.81087226]),
#  'split2_test_precision': array([0.8764719]),
#  'split3_test_precision': array([0.8768033]),
#  'split4_test_precision': array([0.78355065]),
#  'split5_test_precision': array([0.77314906]),
#  'split6_test_precision': array([0.84683293]),
#  'split7_test_precision': array([0.74684305]),
#  'split8_test_precision': array([0.79356223]),
#  'split9_test_precision': array([0.86644737]),
#  'split10_test_precision': array([0.88770549]),
#  'split11_test_precision': array([0.87541061]),
#  'split12_test_precision': array([0.87477915]),
#  'split13_test_precision': array([0.84311905]),
#  'split14_test_precision': array([0.75649043]),
#  'split15_test_precision': array([0.80926657]),
#  'split16_test_precision': array([0.7763466]),
#  'split17_test_precision': array([0.82087358]),
#  'split18_test_precision': array([0.82875984]),
#  'split19_test_precision': array([0.8255132]),
#  'split20_test_precision': array([0.82598608]),
#  'split21_test_precision': array([0.85110491]),
#  'split22_test_precision': array([0.78131459]),
#  'split23_test_precision': array([0.80465691]),
#  'split24_test_precision': array([0.81756909]),
#  'split25_test_precision': array([0.85191676]),
#  'split26_test_precision': array([0.86653688]),
#  'split27_test_precision': array([0.81712143]),
#  'split28_test_precision': array([0.89564583]),
#  'split29_test_precision': array([0.83941606]),
#  'mean_test_precision': array([0.82603841]),
#  'std_test_precision': array([0.04131182]),
#  'rank_test_precision': array([1], dtype=int32),
#  'split0_train_precision': array([0.84965451]),
#  'split1_train_precision': array([0.84025998]),
#  'split2_train_precision': array([0.84555108]),
#  'split3_train_precision': array([0.84834935]),
#  'split4_train_precision': array([0.83995439]),
#  'split5_train_precision': array([0.83815226]),
#  'split6_train_precision': array([0.84511582]),
#  'split7_train_precision': array([0.84391384]),
#  'split8_train_precision': array([0.84206353]),
#  'split9_train_precision': array([0.83661683]),
#  'split10_train_precision': array([0.84550116]),
#  'split11_train_precision': array([0.84241128]),
#  'split12_train_precision': array([0.84007885]),
#  'split13_train_precision': array([0.84901286]),
#  'split14_train_precision': array([0.83799748]),
#  'split15_train_precision': array([0.85263215]),
#  'split16_train_precision': array([0.83904824]),
#  'split17_train_precision': array([0.83379514]),
#  'split18_train_precision': array([0.84568402]),
#  'split19_train_precision': array([0.85150107]),
#  'split20_train_precision': array([0.8387367]),
#  'split21_train_precision': array([0.83650547]),
#  'split22_train_precision': array([0.8344977]),
#  'split23_train_precision': array([0.84441881]),
#  'split24_train_precision': array([0.84187962]),
#  'split25_train_precision': array([0.8360475]),
#  'split26_train_precision': array([0.83041475]),
#  'split27_train_precision': array([0.8467099]),
#  'split28_train_precision': array([0.8461562]),
#  'split29_train_precision': array([0.84281818]),
#  'mean_train_precision': array([0.84218262]),
#  'std_train_precision': array([0.00536]),
#  'split0_test_recall': array([0.95481629]),
#  'split1_test_recall': array([0.97393247]),
#  'split2_test_recall': array([0.97939424]),
#  'split3_test_recall': array([0.95059583]),
#  'split4_test_recall': array([0.96971202]),
#  'split5_test_recall': array([0.97219464]),
#  'split6_test_recall': array([0.95258193]),
#  'split7_test_recall': array([0.92502483]),
#  'split8_test_recall': array([0.91807349]),
#  'split9_test_recall': array([0.98088381]),
#  'split10_test_recall': array([0.95183714]),
#  'split11_test_recall': array([0.92626614]),
#  'split12_test_recall': array([0.98336643]),
#  'split13_test_recall': array([0.90193644]),
#  'split14_test_recall': array([0.99106256]),
#  'split15_test_recall': array([0.96698113]),
#  'split16_test_recall': array([0.98758689]),
#  'split17_test_recall': array([0.9704568]),
#  'split18_test_recall': array([0.96722939]),
#  'split19_test_recall': array([0.97840119]),
#  'split20_test_recall': array([0.97219464]),
#  'split21_test_recall': array([0.98485601]),
#  'split22_test_recall': array([0.93843098]),
#  'split23_test_recall': array([0.96946375]),
#  'split24_test_recall': array([0.90342602]),
#  'split25_test_recall': array([0.96549156]),
#  'split26_test_recall': array([0.99453823]),
#  'split27_test_recall': array([0.97393247]),
#  'split28_test_recall': array([0.91410129]),
#  'split29_test_recall': array([0.94215492]),
#  'mean_test_recall': array([0.95869745]),
#  'std_test_recall': array([0.02589145]),
#  'rank_test_recall': array([1], dtype=int32),
#  'split0_train_recall': array([0.93581139]),
#  'split1_train_recall': array([0.94295107]),
#  'split2_train_recall': array([0.93391946]),
#  'split3_train_recall': array([0.9323186]),
#  'split4_train_recall': array([0.94593021]),
#  'split5_train_recall': array([0.94673492]),
#  'split6_train_recall': array([0.93824265]),
#  'split7_train_recall': array([0.93978358]),
#  'split8_train_recall': array([0.94558778]),
#  'split9_train_recall': array([0.94992809]),
#  'split10_train_recall': array([0.93581139]),
#  'split11_train_recall': array([0.94390131]),
#  'split12_train_recall': array([0.94123035]),
#  'split13_train_recall': array([0.9372924]),
#  'split14_train_recall': array([0.94490292]),
#  'split15_train_recall': array([0.93716399]),
#  'split16_train_recall': array([0.94307092]),
#  'split17_train_recall': array([0.94800192]),
#  'split18_train_recall': array([0.9364192]),
#  'split19_train_recall': array([0.94283122]),
#  'split20_train_recall': array([0.94281409]),
#  'split21_train_recall': array([0.9455193]),
#  'split22_train_recall': array([0.95610896]),
#  'split23_train_recall': array([0.94000616]),
#  'split24_train_recall': array([0.9430966]),
#  'split25_train_recall': array([0.94799336]),
#  'split26_train_recall': array([0.9552272]),
#  'split27_train_recall': array([0.94557922]),
#  'split28_train_recall': array([0.9473513]),
#  'split29_train_recall': array([0.93909016]),
#  'mean_train_recall': array([0.94282066]),
#  'std_train_recall': array([0.00563979])}
# {'keras__activation': 'relu',
#  'keras__activation2': 'relu',
#  'keras__activation_final': 'softmax',
#  'keras__batch_size': 1024,
#  'keras__dropout_rate': 0.3,
#  'keras__epochs': 128,
#  'keras__hidden_layers': 1,
#  'keras__hidden_neurons': 10,
#  'keras__init_mode': 'uniform',
#  'keras__learn_rate': 0.01,
#  'keras__momentum': 0.0,
#  'keras__neurons': 10,
#  'keras__optimizer': 'Adam',
#  'keras__weight_constraint': 2}
# {'accuracy': 0.876895067858325,
#  'precision': 0.8260384142381125,
#  'recall': 0.9586974511751076}
