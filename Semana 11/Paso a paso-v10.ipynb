# %%
import sys
sys.path.append('./libs')
import util_modelo_final
import importlib

importlib.reload(util_modelo_final)
# probar relu y al final softmax
#bmc bioinformatics
batch_size = [2**10]
epochs = [2**7]
optimizer = ['Adam']
learn_rate = [0.01]
momentum = [0.0]
init_mode = ['uniform']
activation = ['relu']
activation2 = ['relu']
activation_final = ['softmax']
dropout_rate = [0.3, 0.6]
weight_constraint = [2, 4]
neurons = [10]
hidden_layers = [4]
hidden_neurons = [100]
tuned_parameters = [{'keras__batch_size': batch_size, 'keras__epochs': epochs, 'keras__optimizer': optimizer, 'keras__learn_rate': learn_rate, 'keras__momentum': momentum, 'keras__init_mode': init_mode, 'keras__activation': activation, 'keras__activation2': activation2, 'keras__dropout_rate': dropout_rate, 'keras__weight_constraint': weight_constraint, 'keras__neurons': neurons, 'keras__hidden_layers': hidden_layers, 'keras__hidden_neurons': hidden_neurons, 'keras__activation_final': activation_final}]
tesis2 = util_modelo_final.Tesis2(carpeta_base="real",verbose=100,tuned_parameters=tuned_parameters)
# Out:
# Using TensorFlow backend.

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

if (tesis2.verbose > 1): print("*************************************************")
if (tesis2.verbose > 1): print("************ Generando modelo final *************")
if (tesis2.verbose > 1): print("*************************************************")
# %time tesis2.entrenar_modelo_final_keras()
tesis2.modelo_final_generado = True
if (tesis2.verbose > 1):
    print("*************************************************")
    print("************* Mostrando resultados **************")
    print("*************************************************")
    tesis2.mostrar_resultados()
# Out:
# *************************************************
# ************ Generando modelo final *************
# *************************************************
# Fitting 30 folds for each of 4 candidates, totalling 120 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-658e4d053722410da39eab91b8e090c7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2c179f24711c4b48899e6c9b7da1930f.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a044f1279b4e41889804815294745f41.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-058ec20e5b51461c9b387e5c66778747.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a71caf066d8449fc9b690aa5464df743.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed: 25.0min
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed: 25.0min
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed: 25.0min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-dc5f27f031d940be86ecc973954b3216.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed: 25.1min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-6c96821e60f54796b1c93fcdab18e6f8.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-e054dbc6f28a43caac236a51ed2e54e2.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-531e9755e8914ad497b8e6cf99f4b9e6.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed: 49.6min
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed: 49.7min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-043d2afad9b441c2beab83f2054a9dad.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed: 49.8min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1790c144541346b2916afcc751b4e7a4.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0f85f484cb274d58a3bec44f02d0596c.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed: 50.0min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0b1031a8248b4ddc9be6400a3ebeefdb.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed: 74.2min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-afaa8959d602408f8d3f14fd844f245d.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed: 74.4min
# [Parallel(n_jobs=-1)]: Done  11 tasks      | elapsed: 74.5min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-82ed030183734e0389d6f793fc2a4eec.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-8f0a91cd5353479d871fb931dbeecf2e.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed: 74.7min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-d861a90d124c40eea08ef210539288cd.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  13 tasks      | elapsed: 99.0min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-89b4e4a99f774ab8a7fcaf9a65c66cae.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed: 99.2min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-c86f1b6d7c7546bd89e965e771a94f18.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed: 99.4min
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed: 99.5min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1d5b991196d844c3857ea8636695a0ac.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a574f27d30564f4faf540b0848026782.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed: 123.7min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1fd874d89bd2450bb7837a1dd215887c.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed: 124.1min
# [Parallel(n_jobs=-1)]: Done  19 tasks      | elapsed: 124.2min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-00aadb95847a431cacf3b0d89ccb7ff7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-888de9c3150a46d6b30c965d8a8bc0df.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed: 124.4min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-8d928f3aabb3467785b21bfd9d77053d.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  21 tasks      | elapsed: 148.5min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-27b30049d9b342878ab123cec7dc18c9.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  22 tasks      | elapsed: 149.1min
# [Parallel(n_jobs=-1)]: Done  23 tasks      | elapsed: 149.1min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0e34cd379ac244ffb45181a72446473b.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  24 tasks      | elapsed: 149.3min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2685c6abc7954d7b910835c827e11ff7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2595e8833d4c41cca2ceb1eb8927a90a.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed: 173.2min
# Memmapping (shape=(233624,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-7d40a20858364ad6a6f37f66d18725e8.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed: 173.9min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-658e4d053722410da39eab91b8e090c7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  27 tasks      | elapsed: 174.1min
# [Parallel(n_jobs=-1)]: Done  28 tasks      | elapsed: 174.2min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2c179f24711c4b48899e6c9b7da1930f.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a044f1279b4e41889804815294745f41.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  29 tasks      | elapsed: 198.0min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-058ec20e5b51461c9b387e5c66778747.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  30 tasks      | elapsed: 198.9min
# [Parallel(n_jobs=-1)]: Done  31 tasks      | elapsed: 199.0min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a71caf066d8449fc9b690aa5464df743.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  32 tasks      | elapsed: 199.1min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-dc5f27f031d940be86ecc973954b3216.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-6c96821e60f54796b1c93fcdab18e6f8.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed: 223.2min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-e054dbc6f28a43caac236a51ed2e54e2.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed: 224.2min
# [Parallel(n_jobs=-1)]: Done  35 tasks      | elapsed: 224.3min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-531e9755e8914ad497b8e6cf99f4b9e6.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  36 tasks      | elapsed: 224.4min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-043d2afad9b441c2beab83f2054a9dad.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1790c144541346b2916afcc751b4e7a4.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  37 tasks      | elapsed: 247.9min
# /home/jose/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0f85f484cb274d58a3bec44f02d0596c.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  38 tasks      | elapsed: 248.9min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0b1031a8248b4ddc9be6400a3ebeefdb.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  39 tasks      | elapsed: 249.0min
# [Parallel(n_jobs=-1)]: Done  40 tasks      | elapsed: 249.1min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-afaa8959d602408f8d3f14fd844f245d.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-82ed030183734e0389d6f793fc2a4eec.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  41 tasks      | elapsed: 273.0min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-8f0a91cd5353479d871fb931dbeecf2e.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 273.4min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-d861a90d124c40eea08ef210539288cd.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  43 tasks      | elapsed: 273.6min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-89b4e4a99f774ab8a7fcaf9a65c66cae.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  44 tasks      | elapsed: 273.7min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-c86f1b6d7c7546bd89e965e771a94f18.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  45 tasks      | elapsed: 297.4min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1d5b991196d844c3857ea8636695a0ac.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed: 298.0min
# [Parallel(n_jobs=-1)]: Done  47 tasks      | elapsed: 298.0min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a574f27d30564f4faf540b0848026782.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  48 tasks      | elapsed: 298.2min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1fd874d89bd2450bb7837a1dd215887c.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-00aadb95847a431cacf3b0d89ccb7ff7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  49 tasks      | elapsed: 321.9min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-888de9c3150a46d6b30c965d8a8bc0df.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  50 tasks      | elapsed: 322.5min
# [Parallel(n_jobs=-1)]: Done  51 tasks      | elapsed: 322.6min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-8d928f3aabb3467785b21bfd9d77053d.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed: 322.7min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-27b30049d9b342878ab123cec7dc18c9.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0e34cd379ac244ffb45181a72446473b.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  53 tasks      | elapsed: 346.4min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2685c6abc7954d7b910835c827e11ff7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  54 tasks      | elapsed: 347.2min
# [Parallel(n_jobs=-1)]: Done  55 tasks      | elapsed: 347.2min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2595e8833d4c41cca2ceb1eb8927a90a.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed: 347.3min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-7d40a20858364ad6a6f37f66d18725e8.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-658e4d053722410da39eab91b8e090c7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  57 tasks      | elapsed: 370.9min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2c179f24711c4b48899e6c9b7da1930f.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed: 371.8min
# [Parallel(n_jobs=-1)]: Done  59 tasks      | elapsed: 371.9min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a044f1279b4e41889804815294745f41.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  60 tasks      | elapsed: 372.0min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-058ec20e5b51461c9b387e5c66778747.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a71caf066d8449fc9b690aa5464df743.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  61 tasks      | elapsed: 395.7min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-dc5f27f031d940be86ecc973954b3216.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  62 tasks      | elapsed: 396.7min
# [Parallel(n_jobs=-1)]: Done  63 tasks      | elapsed: 396.7min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-6c96821e60f54796b1c93fcdab18e6f8.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  64 tasks      | elapsed: 396.8min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-e054dbc6f28a43caac236a51ed2e54e2.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-531e9755e8914ad497b8e6cf99f4b9e6.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  65 tasks      | elapsed: 420.3min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-043d2afad9b441c2beab83f2054a9dad.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  66 tasks      | elapsed: 421.4min
# [Parallel(n_jobs=-1)]: Done  67 tasks      | elapsed: 421.5min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1790c144541346b2916afcc751b4e7a4.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  68 tasks      | elapsed: 421.6min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0f85f484cb274d58a3bec44f02d0596c.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0b1031a8248b4ddc9be6400a3ebeefdb.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  69 tasks      | elapsed: 444.9min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-afaa8959d602408f8d3f14fd844f245d.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  70 tasks      | elapsed: 446.2min
# [Parallel(n_jobs=-1)]: Done  71 tasks      | elapsed: 446.3min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-82ed030183734e0389d6f793fc2a4eec.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  72 tasks      | elapsed: 446.4min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-8f0a91cd5353479d871fb931dbeecf2e.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-d861a90d124c40eea08ef210539288cd.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  73 tasks      | elapsed: 469.5min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-89b4e4a99f774ab8a7fcaf9a65c66cae.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  74 tasks      | elapsed: 471.1min
# [Parallel(n_jobs=-1)]: Done  75 tasks      | elapsed: 471.1min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-c86f1b6d7c7546bd89e965e771a94f18.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  76 tasks      | elapsed: 471.3min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1d5b991196d844c3857ea8636695a0ac.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a574f27d30564f4faf540b0848026782.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  77 tasks      | elapsed: 494.3min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1fd874d89bd2450bb7837a1dd215887c.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  78 tasks      | elapsed: 495.8min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-00aadb95847a431cacf3b0d89ccb7ff7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  79 tasks      | elapsed: 496.0min
# [Parallel(n_jobs=-1)]: Done  80 tasks      | elapsed: 496.0min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-888de9c3150a46d6b30c965d8a8bc0df.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-8d928f3aabb3467785b21bfd9d77053d.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  81 tasks      | elapsed: 519.6min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-27b30049d9b342878ab123cec7dc18c9.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  82 tasks      | elapsed: 520.9min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0e34cd379ac244ffb45181a72446473b.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  83 tasks      | elapsed: 521.1min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2685c6abc7954d7b910835c827e11ff7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  84 tasks      | elapsed: 521.3min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2595e8833d4c41cca2ceb1eb8927a90a.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  85 tasks      | elapsed: 544.3min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-7d40a20858364ad6a6f37f66d18725e8.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  86 tasks      | elapsed: 545.9min
# [Parallel(n_jobs=-1)]: Done  87 tasks      | elapsed: 546.0min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-658e4d053722410da39eab91b8e090c7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2c179f24711c4b48899e6c9b7da1930f.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  88 tasks      | elapsed: 546.2min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a044f1279b4e41889804815294745f41.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  89 tasks      | elapsed: 569.2min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-058ec20e5b51461c9b387e5c66778747.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  90 tasks      | elapsed: 570.8min
# [Parallel(n_jobs=-1)]: Done  91 tasks      | elapsed: 570.8min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a71caf066d8449fc9b690aa5464df743.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-dc5f27f031d940be86ecc973954b3216.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  92 tasks      | elapsed: 571.1min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-6c96821e60f54796b1c93fcdab18e6f8.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  93 tasks      | elapsed: 594.0min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-e054dbc6f28a43caac236a51ed2e54e2.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  94 tasks      | elapsed: 595.7min
# [Parallel(n_jobs=-1)]: Done  95 tasks      | elapsed: 595.8min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-531e9755e8914ad497b8e6cf99f4b9e6.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  96 tasks      | elapsed: 595.9min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-043d2afad9b441c2beab83f2054a9dad.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1790c144541346b2916afcc751b4e7a4.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  97 tasks      | elapsed: 618.8min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0f85f484cb274d58a3bec44f02d0596c.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done  98 tasks      | elapsed: 620.6min
# [Parallel(n_jobs=-1)]: Done  99 tasks      | elapsed: 620.7min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0b1031a8248b4ddc9be6400a3ebeefdb.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 100 tasks      | elapsed: 620.8min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-afaa8959d602408f8d3f14fd844f245d.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-82ed030183734e0389d6f793fc2a4eec.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 101 tasks      | elapsed: 643.6min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-8f0a91cd5353479d871fb931dbeecf2e.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 102 tasks      | elapsed: 645.5min
# [Parallel(n_jobs=-1)]: Done 103 tasks      | elapsed: 645.6min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-d861a90d124c40eea08ef210539288cd.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 104 tasks      | elapsed: 645.7min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-89b4e4a99f774ab8a7fcaf9a65c66cae.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-c86f1b6d7c7546bd89e965e771a94f18.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 105 tasks      | elapsed: 668.3min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1d5b991196d844c3857ea8636695a0ac.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 106 tasks      | elapsed: 670.4min
# [Parallel(n_jobs=-1)]: Done 107 tasks      | elapsed: 670.4min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-a574f27d30564f4faf540b0848026782.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 108 tasks      | elapsed: 670.6min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-1fd874d89bd2450bb7837a1dd215887c.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-00aadb95847a431cacf3b0d89ccb7ff7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 109 tasks      | elapsed: 693.0min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-888de9c3150a46d6b30c965d8a8bc0df.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 110 tasks      | elapsed: 695.2min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-8d928f3aabb3467785b21bfd9d77053d.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 111 tasks      | elapsed: 695.3min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-27b30049d9b342878ab123cec7dc18c9.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 112 tasks      | elapsed: 695.5min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-0e34cd379ac244ffb45181a72446473b.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 113 tasks      | elapsed: 717.8min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2685c6abc7954d7b910835c827e11ff7.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 115 out of 120 | elapsed: 720.2min remaining: 31.3min
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-2595e8833d4c41cca2ceb1eb8927a90a.pkl
# Pickling array (shape=(8056,), dtype=int64).
# Memmapping (shape=(233624,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3679_7714055615/3679-139674144359704-7d40a20858364ad6a6f37f66d18725e8.pkl
# Pickling array (shape=(8056,), dtype=int64).
# [Parallel(n_jobs=-1)]: Done 117 out of 120 | elapsed: 742.7min remaining: 19.0min
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed: 744.6min finished
# WARNING:tensorflow:From /home/jose/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/jose/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/jose/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# CPU times: user 32min 38s, sys: 45.7 s, total: 33min 23s
# Wall time: 12h 32min 36s
# *************************************************
# ************* Mostrando resultados **************
# *************************************************
# {'mean_fit_time': array([1416.10786707, 1407.03588607, 1409.0838327 , 1410.1119372 ]),
#  'std_fit_time': array([ 6.24940503, 16.48335976, 10.78536638,  9.12886742]),
#  'mean_score_time': array([3.05469947, 2.99822351, 2.818039  , 2.87238369]),
#  'std_score_time': array([0.41105773, 0.59253721, 0.44879443, 0.40153456]),
#  'param_keras__activation': masked_array(data=['relu', 'relu', 'relu', 'relu'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__activation2': masked_array(data=['relu', 'relu', 'relu', 'relu'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__activation_final': masked_array(data=['softmax', 'softmax', 'softmax', 'softmax'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__batch_size': masked_array(data=[1024, 1024, 1024, 1024],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__dropout_rate': masked_array(data=[0.3, 0.3, 0.6, 0.6],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__epochs': masked_array(data=[128, 128, 128, 128],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__hidden_layers': masked_array(data=[4, 4, 4, 4],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__hidden_neurons': masked_array(data=[100, 100, 100, 100],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__init_mode': masked_array(data=['uniform', 'uniform', 'uniform', 'uniform'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__learn_rate': masked_array(data=[0.01, 0.01, 0.01, 0.01],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__momentum': masked_array(data=[0.0, 0.0, 0.0, 0.0],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__neurons': masked_array(data=[10, 10, 10, 10],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__optimizer': masked_array(data=['Adam', 'Adam', 'Adam', 'Adam'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_keras__weight_constraint': masked_array(data=[2, 4, 2, 4],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'keras__activation': 'relu',
#    'keras__activation2': 'relu',
#    'keras__activation_final': 'softmax',
#    'keras__batch_size': 1024,
#    'keras__dropout_rate': 0.3,
#    'keras__epochs': 128,
#    'keras__hidden_layers': 4,
#    'keras__hidden_neurons': 100,
#    'keras__init_mode': 'uniform',
#    'keras__learn_rate': 0.01,
#    'keras__momentum': 0.0,
#    'keras__neurons': 10,
#    'keras__optimizer': 'Adam',
#    'keras__weight_constraint': 2},
#   {'keras__activation': 'relu',
#    'keras__activation2': 'relu',
#    'keras__activation_final': 'softmax',
#    'keras__batch_size': 1024,
#    'keras__dropout_rate': 0.3,
#    'keras__epochs': 128,
#    'keras__hidden_layers': 4,
#    'keras__hidden_neurons': 100,
#    'keras__init_mode': 'uniform',
#    'keras__learn_rate': 0.01,
#    'keras__momentum': 0.0,
#    'keras__neurons': 10,
#    'keras__optimizer': 'Adam',
#    'keras__weight_constraint': 4},
#   {'keras__activation': 'relu',
#    'keras__activation2': 'relu',
#    'keras__activation_final': 'softmax',
#    'keras__batch_size': 1024,
#    'keras__dropout_rate': 0.6,
#    'keras__epochs': 128,
#    'keras__hidden_layers': 4,
#    'keras__hidden_neurons': 100,
#    'keras__init_mode': 'uniform',
#    'keras__learn_rate': 0.01,
#    'keras__momentum': 0.0,
#    'keras__neurons': 10,
#    'keras__optimizer': 'Adam',
#    'keras__weight_constraint': 2},
#   {'keras__activation': 'relu',
#    'keras__activation2': 'relu',
#    'keras__activation_final': 'softmax',
#    'keras__batch_size': 1024,
#    'keras__dropout_rate': 0.6,
#    'keras__epochs': 128,
#    'keras__hidden_layers': 4,
#    'keras__hidden_neurons': 100,
#    'keras__init_mode': 'uniform',
#    'keras__learn_rate': 0.01,
#    'keras__momentum': 0.0,
#    'keras__neurons': 10,
#    'keras__optimizer': 'Adam',
#    'keras__weight_constraint': 4}],
#  'split0_test_accuracy': array([0.82671301, 0.82063059, 0.74751738, 0.77966733]),
#  'split1_test_accuracy': array([0.84831182, 0.84309831, 0.81864449, 0.82658888]),
#  'split2_test_accuracy': array([0.90193644, 0.89560576, 0.89324727, 0.81479643]),
#  'split3_test_accuracy': array([0.89486097, 0.8917577 , 0.83726415, 0.90950844]),
#  'split4_test_accuracy': array([0.82323734, 0.82944389, 0.82261668, 0.79419067]),
#  'split5_test_accuracy': array([0.82845084, 0.82025819, 0.79046673, 0.78525323]),
#  'split6_test_accuracy': array([0.85886296, 0.88679245, 0.79282522, 0.82658888]),
#  'split7_test_accuracy': array([0.83726415, 0.84781529, 0.77991559, 0.77656405]),
#  'split8_test_accuracy': array([0.82584409, 0.83167825, 0.82323734, 0.81256207]),
#  'split9_test_accuracy': array([0.89548163, 0.8969712 , 0.88642006, 0.87735849]),
#  'split10_test_accuracy': array([0.89784012, 0.90479146, 0.88803376, 0.88095829]),
#  'split11_test_accuracy': array([0.87152433, 0.87053128, 0.84893247, 0.80325223]),
#  'split12_test_accuracy': array([0.90081927, 0.90330189, 0.88430983, 0.88828203]),
#  'split13_test_accuracy': array([0.85948361, 0.85960775, 0.85042205, 0.8218719 ]),
#  'split14_test_accuracy': array([0.83304369, 0.82559583, 0.79208044, 0.77892254]),
#  'split15_test_accuracy': array([0.85613208, 0.86655909, 0.78761172, 0.85228401]),
#  'split16_test_accuracy': array([0.84086395, 0.84235353, 0.81181728, 0.81889275]),
#  'split17_test_accuracy': array([0.87388282, 0.87028302, 0.89051639, 0.82931976]),
#  'split18_test_accuracy': array([0.87437934, 0.8658143 , 0.83242304, 0.84707051]),
#  'split19_test_accuracy': array([0.87115194, 0.867428  , 0.86916584, 0.82894737]),
#  'split20_test_accuracy': array([0.8714002 , 0.88083416, 0.85191162, 0.82100298]),
#  'split21_test_accuracy': array([0.89759186, 0.89647468, 0.84049156, 0.85935948]),
#  'split22_test_accuracy': array([0.82087885, 0.81653426, 0.76266137, 0.80287984]),
#  'split23_test_accuracy': array([0.84918073, 0.84247766, 0.80114201, 0.79108739]),
#  'split24_test_accuracy': array([0.87239325, 0.83316783, 0.82956802, 0.8123138 ]),
#  'split25_test_accuracy': array([0.89585402, 0.89275074, 0.87189672, 0.87996524]),
#  'split26_test_accuracy': array([0.89560576, 0.91770109, 0.89610228, 0.87984111]),
#  'split27_test_accuracy': array([0.85451837, 0.85427011, 0.80337637, 0.81380338]),
#  'split28_test_accuracy': array([0.92303873, 0.92204568, 0.90355015, 0.90268123]),
#  'split29_test_accuracy': array([0.86097319, 0.86097319, 0.83142999, 0.841857  ]),
#  'mean_test_accuracy': array([0.86538398, 0.86525157, 0.83465326, 0.83192238]),
#  'std_test_accuracy': array([0.02793135, 0.0302899 , 0.04208554, 0.03748505]),
#  'rank_test_accuracy': array([1, 2, 3, 4], dtype=int32),
#  'split0_train_accuracy': array([0.87297966, 0.86915728, 0.80347909, 0.85254512]),
#  'split1_train_accuracy': array([0.87331353, 0.8744992 , 0.8555157 , 0.85929956]),
#  'split2_train_accuracy': array([0.87306527, 0.86819847, 0.86576294, 0.79162672]),
#  'split3_train_accuracy': array([0.86705989, 0.86557032, 0.82440588, 0.87917337]),
#  'split4_train_accuracy': array([0.87337774, 0.87221347, 0.86971373, 0.85117111]),
#  'split5_train_accuracy': array([0.87546656, 0.87247885, 0.85320429, 0.85188594]),
#  'split6_train_accuracy': array([0.86162809, 0.88541417, 0.81305003, 0.84118926]),
#  'split7_train_accuracy': array([0.87172979, 0.87632264, 0.83870664, 0.83697308]),
#  'split8_train_accuracy': array([0.87195665, 0.88136493, 0.86091326, 0.85059754]),
#  'split9_train_accuracy': array([0.87069822, 0.86521505, 0.84699346, 0.84462213]),
#  'split10_train_accuracy': array([0.86988494, 0.87175975, 0.85224121, 0.84705767]),
#  'split11_train_accuracy': array([0.87638684, 0.87580899, 0.829705  , 0.78182036]),
#  'split12_train_accuracy': array([0.87538523, 0.87453772, 0.85724926, 0.85320001]),
#  'split13_train_accuracy': array([0.88063726, 0.88023491, 0.86117865, 0.81070438]),
#  'split14_train_accuracy': array([0.88039328, 0.87405832, 0.85093141, 0.83026573]),
#  'split15_train_accuracy': array([0.8724917 , 0.88217392, 0.80795209, 0.86194055]),
#  'split16_train_accuracy': array([0.87252594, 0.87161422, 0.84336798, 0.85758313]),
#  'split17_train_accuracy': array([0.87717015, 0.87175975, 0.87223915, 0.83806886]),
#  'split18_train_accuracy': array([0.87491011, 0.86612249, 0.82884464, 0.84627864]),
#  'split19_train_accuracy': array([0.86266822, 0.87460192, 0.85988597, 0.82948242]),
#  'split20_train_accuracy': array([0.87352755, 0.87637828, 0.85356385, 0.82375526]),
#  'split21_train_accuracy': array([0.87701178, 0.87228196, 0.8302058 , 0.84578211]),
#  'split22_train_accuracy': array([0.87198233, 0.87048848, 0.80418536, 0.83988803]),
#  'split23_train_accuracy': array([0.87337345, 0.87356607, 0.83050115, 0.82707256]),
#  'split24_train_accuracy': array([0.88280742, 0.87948156, 0.85591806, 0.82842516]),
#  'split25_train_accuracy': array([0.87153717, 0.86563452, 0.85047769, 0.84555953]),
#  'split26_train_accuracy': array([0.85666712, 0.87381433, 0.85001969, 0.83932301]),
#  'split27_train_accuracy': array([0.87957145, 0.87423809, 0.83057391, 0.8465483 ]),
#  'split28_train_accuracy': array([0.87925042, 0.87708883, 0.85670993, 0.84745146]),
#  'split29_train_accuracy': array([0.869611  , 0.87515837, 0.84651834, 0.8530074 ]),
#  'mean_train_accuracy': array([0.87296896, 0.8737079 , 0.84346714, 0.84040995]),
#  'std_train_accuracy': array([0.00554797, 0.00489213, 0.0188311 , 0.01933329]),
#  'split0_test_precision': array([0.75009502, 0.73956594, 0.66446717, 0.69412373]),
#  'split1_test_precision': array([0.77628988, 0.77409758, 0.73968254, 0.74910055]),
#  'split2_test_precision': array([0.84213863, 0.83204834, 0.83013756, 0.73012704]),
#  'split3_test_precision': array([0.82868361, 0.82442434, 0.75521323, 0.87059088]),
#  'split4_test_precision': array([0.75077042, 0.75343774, 0.74710021, 0.71305286]),
#  'split5_test_precision': array([0.75589942, 0.74665392, 0.70982783, 0.70228873]),
#  'split6_test_precision': array([0.78709037, 0.84151688, 0.70798801, 0.7454749 ]),
#  'split7_test_precision': array([0.76445396, 0.78189135, 0.69874846, 0.69482336]),
#  'split8_test_precision': array([0.77224642, 0.77914751, 0.75340599, 0.73718915]),
#  'split9_test_precision': array([0.83579258, 0.83050847, 0.81707069, 0.80460922]),
#  'split10_test_precision': array([0.83281412, 0.84319091, 0.8196319 , 0.80881465]),
#  'split11_test_precision': array([0.84174469, 0.84765898, 0.78549665, 0.72020912]),
#  'split12_test_precision': array([0.84593958, 0.85430752, 0.81604737, 0.8223413 ]),
#  'split13_test_precision': array([0.82789855, 0.82397674, 0.8043994 , 0.74211018]),
#  'split14_test_precision': array([0.75098223, 0.74184031, 0.70658472, 0.69347339]),
#  'split15_test_precision': array([0.79377432, 0.80843952, 0.70257038, 0.78233187]),
#  'split16_test_precision': array([0.76816406, 0.76996868, 0.72861303, 0.73642555]),
#  'split17_test_precision': array([0.83142606, 0.82445073, 0.86294416, 0.75014143]),
#  'split18_test_precision': array([0.81949153, 0.80463097, 0.75264151, 0.77145631]),
#  'split19_test_precision': array([0.79650932, 0.79202841, 0.79609717, 0.74591685]),
#  'split20_test_precision': array([0.79623762, 0.81014962, 0.77317402, 0.73681319]),
#  'split21_test_precision': array([0.83371536, 0.829007  , 0.75814041, 0.78079534]),
#  'split22_test_precision': array([0.76491084, 0.76342975, 0.68042292, 0.72812266]),
#  'split23_test_precision': array([0.78124375, 0.76822866, 0.71832253, 0.7074854 ]),
#  'split24_test_precision': array([0.82523851, 0.84304703, 0.75553417, 0.73167587]),
#  'split25_test_precision': array([0.83101515, 0.82862484, 0.79936051, 0.81000608]),
#  'split26_test_precision': array([0.83025907, 0.86299892, 0.82958067, 0.80759952]),
#  'split27_test_precision': array([0.78221344, 0.78257426, 0.71907494, 0.73252391]),
#  'split28_test_precision': array([0.88727273, 0.88548753, 0.85592293, 0.85445804]),
#  'split29_test_precision': array([0.80367586, 0.8041841 , 0.75892164, 0.77245746]),
#  'mean_test_precision': array([0.80359957, 0.80638389, 0.76157076, 0.75588462]),
#  'std_test_precision': array([0.03504763, 0.03804233, 0.05189506, 0.04611644]),
#  'rank_test_precision': array([2, 1, 3, 4], dtype=int32),
#  'split0_train_precision': array([0.81613758, 0.80187332, 0.71936067, 0.7789791 ]),
#  'split1_train_precision': array([0.80854436, 0.81526831, 0.78387985, 0.78997768]),
#  'split2_train_precision': array([0.81302571, 0.80522596, 0.80301128, 0.70681731]),
#  'split3_train_precision': array([0.80383792, 0.79734566, 0.74264438, 0.8393971 ]),
#  'split4_train_precision': array([0.8138402 , 0.80862874, 0.80891105, 0.77728133]),
#  'split5_train_precision': array([0.81707899, 0.81267067, 0.78040111, 0.7779942 ]),
#  'split6_train_precision': array([0.79295399, 0.83594251, 0.7295226 , 0.76327784]),
#  'split7_train_precision': array([0.80798502, 0.81597447, 0.76088304, 0.75779863]),
#  'split8_train_precision': array([0.81039434, 0.82451885, 0.79184665, 0.77588112]),
#  'split9_train_precision': array([0.81017736, 0.80110953, 0.7719934 , 0.76950526]),
#  'split10_train_precision': array([0.80900106, 0.81209843, 0.77969927, 0.7728475 ]),
#  'split11_train_precision': array([0.81814366, 0.81852416, 0.75000811, 0.69701721]),
#  'split12_train_precision': array([0.81644524, 0.81700275, 0.7871544 , 0.78171303]),
#  'split13_train_precision': array([0.82667921, 0.82509662, 0.79356509, 0.72692827]),
#  'split14_train_precision': array([0.82541066, 0.81577331, 0.77695353, 0.7508518 ]),
#  'split15_train_precision': array([0.81172939, 0.8314143 , 0.72409282, 0.7954466 ]),
#  'split16_train_precision': array([0.81268548, 0.81185074, 0.76713132, 0.78703564]),
#  'split17_train_precision': array([0.82055237, 0.81148058, 0.85834254, 0.75907132]),
#  'split18_train_precision': array([0.81869187, 0.80176398, 0.74862461, 0.7711256 ]),
#  'split19_train_precision': array([0.79701193, 0.8123073 , 0.79048507, 0.750278  ]),
#  'split20_train_precision': array([0.81540274, 0.81915257, 0.78097681, 0.74182327]),
#  'split21_train_precision': array([0.82030824, 0.81418065, 0.75066611, 0.7700779 ]),
#  'split22_train_precision': array([0.80914369, 0.8086554 , 0.71986164, 0.76178608]),
#  'split23_train_precision': array([0.81452689, 0.81210751, 0.75159173, 0.74724642]),
#  'split24_train_precision': array([0.83197844, 0.85341391, 0.78354214, 0.74776864]),
#  'split25_train_precision': array([0.81005315, 0.79973332, 0.77631916, 0.77066053]),
#  'split26_train_precision': array([0.78883697, 0.81534173, 0.77677816, 0.76196582]),
#  'split27_train_precision': array([0.82420427, 0.81654273, 0.75032088, 0.77312166]),
#  'split28_train_precision': array([0.82272423, 0.8207563 , 0.78531518, 0.77290362]),
#  'split29_train_precision': array([0.80747045, 0.81578227, 0.77226957, 0.78027909]),
#  'mean_train_precision': array([0.81316585, 0.81505122, 0.77053841, 0.76522859]),
#  'std_train_precision': array([0.0092986 , 0.01119772, 0.02877672, 0.02591896]),
#  'split0_test_recall': array([0.97989076, 0.98982125, 1.        , 1.        ]),
#  'split1_test_recall': array([0.97864945, 0.96896723, 0.98336643, 0.98212512]),
#  'split2_test_recall': array([0.98932473, 0.99131082, 0.9888282 , 0.99875869]),
#  'split3_test_recall': array([0.99553128, 0.99553128, 0.9980139 , 0.96201589]),
#  'split4_test_recall': array([0.96772592, 0.97939424, 0.97542205, 0.98460775]),
#  'split5_test_recall': array([0.97020854, 0.96946375, 0.98262165, 0.99031778]),
#  'split6_test_recall': array([0.98386296, 0.95307845, 0.99677259, 0.99180735]),
#  'split7_test_recall': array([0.97492552, 0.96474677, 0.98411122, 0.98634558]),
#  'split8_test_recall': array([0.92428004, 0.92576961, 0.96102284, 0.97144985]),
#  'split9_test_recall': array([0.98435948, 0.99751738, 0.99577954, 0.99677259]),
#  'split10_test_recall': array([0.99553128, 0.99453823, 0.99503476, 0.99776564]),
#  'split11_test_recall': array([0.91509434, 0.90342602, 0.96002979, 0.99180735]),
#  'split12_test_recall': array([0.98013903, 0.9724429 , 0.99230387, 0.99056604]),
#  'split13_test_recall': array([0.90764647, 0.91459782, 0.92601787, 0.98659384]),
#  'split14_test_recall': array([0.99652433, 0.99875869, 0.99900695, 0.99975174]),
#  'split15_test_recall': array([0.96226415, 0.96077458, 0.99751738, 0.97616683]),
#  'split16_test_recall': array([0.97641509, 0.97641509, 0.99379345, 0.99329692]),
#  'split17_test_recall': array([0.93793446, 0.9409136 , 0.9285005 , 0.98758689]),
#  'split18_test_recall': array([0.96027805, 0.96623635, 0.99031778, 0.98634558]),
#  'split19_test_recall': array([0.99702085, 0.99652433, 0.99255214, 0.99776564]),
#  'split20_test_recall': array([0.99826216, 0.99478649, 0.99602781, 0.99875869]),
#  'split21_test_recall': array([0.99329692, 0.99900695, 1.        , 0.99925521]),
#  'split22_test_recall': array([0.9265144 , 0.9173287 , 0.99056604, 0.96673287]),
#  'split23_test_recall': array([0.96996028, 0.98088381, 0.9908143 , 0.99255214]),
#  'split24_test_recall': array([0.9448858 , 0.81876862, 0.974429  , 0.98634558]),
#  'split25_test_recall': array([0.99379345, 0.99031778, 0.99304866, 0.9928004 ]),
#  'split26_test_recall': array([0.99453823, 0.99304866, 0.99702085, 0.99726912]),
#  'split27_test_recall': array([0.98262165, 0.98113208, 0.99577954, 0.98857994]),
#  'split28_test_recall': array([0.96921549, 0.96946375, 0.9704568 , 0.97070506]),
#  'split29_test_recall': array([0.95531281, 0.95431976, 0.97144985, 0.96921549]),
#  'mean_test_recall': array([0.97020026, 0.9653095 , 0.98402019, 0.98780205]),
#  'std_test_recall': array([0.02545363, 0.03791048, 0.0187249 , 0.01057603]),
#  'rank_test_recall': array([3, 4, 2, 1], dtype=int32),
#  'split0_train_recall': array([0.96288053, 0.98060131, 0.99521453, 0.98439373]),
#  'split1_train_recall': array([0.97827278, 0.96843646, 0.98168853, 0.97882923]),
#  'split2_train_recall': array([0.96896723, 0.97135568, 0.96930966, 0.9966613 ]),
#  'split3_train_recall': array([0.97109886, 0.98029312, 0.992886  , 0.9377718 ]),
#  'split4_train_recall': array([0.968231  , 0.97522515, 0.96812827, 0.98441085]),
#  'split5_train_recall': array([0.96753758, 0.96811971, 0.983024  , 0.98478752]),
#  'split6_train_recall': array([0.97883779, 0.9590453 , 0.99500907, 0.98915351]),
#  'split7_train_recall': array([0.97521659, 0.97181796, 0.98786084, 0.99053179]),
#  'split8_train_recall': array([0.97112454, 0.96895011, 0.97924015, 0.98601171]),
#  'split9_train_recall': array([0.96825669, 0.97166387, 0.98486457, 0.98398281]),
#  'split10_train_recall': array([0.96840222, 0.96734068, 0.98191967, 0.98304969]),
#  'split11_train_recall': array([0.96792282, 0.96573126, 0.98909359, 0.99703798]),
#  'split12_train_recall': array([0.96851351, 0.9652861 , 0.97930007, 0.9800791 ]),
#  'split13_train_recall': array([0.96322296, 0.96503784, 0.97633805, 0.99529158]),
#  'split14_train_recall': array([0.96487518, 0.96634764, 0.9844879 , 0.98855426]),
#  'split15_train_recall': array([0.96995172, 0.95875424, 0.99506044, 0.9744718 ]),
#  'split16_train_recall': array([0.96821388, 0.96743485, 0.98606308, 0.9804729 ]),
#  'split17_train_recall': array([0.965483  , 0.96852207, 0.89162928, 0.99053179]),
#  'split18_train_recall': array([0.96311167, 0.97275965, 0.99017224, 0.98487313]),
#  'split19_train_recall': array([0.97319625, 0.97433483, 0.97934288, 0.9877153 ]),
#  'split20_train_recall': array([0.96567134, 0.96603089, 0.98273294, 0.99315995]),
#  'split21_train_recall': array([0.9655258 , 0.96474677, 0.98886245, 0.98593466]),
#  'split22_train_recall': array([0.97361572, 0.9706537 , 0.99595076, 0.98905934]),
#  'split23_train_recall': array([0.96692121, 0.97202342, 0.98732151, 0.98850289]),
#  'split24_train_recall': array([0.95936205, 0.91636133, 0.98354621, 0.99119097]),
#  'split25_train_recall': array([0.97068794, 0.97556758, 0.98466767, 0.98392288]),
#  'split26_train_recall': array([0.97408657, 0.96652741, 0.98233058, 0.98697052]),
#  'split27_train_recall': array([0.96496079, 0.96537171, 0.99087423, 0.98096942]),
#  'split28_train_recall': array([0.96682704, 0.96490087, 0.9818255 , 0.98403417]),
#  'split29_train_recall': array([0.97066226, 0.96917269, 0.98286991, 0.98275006]),
#  'mean_train_recall': array([0.96872125, 0.96728047, 0.98172049, 0.98483689]),
#  'std_train_recall': array([0.00440166, 0.01068023, 0.01802609, 0.01012763])}
# {'keras__activation': 'relu',
#  'keras__activation2': 'relu',
#  'keras__activation_final': 'softmax',
#  'keras__batch_size': 1024,
#  'keras__dropout_rate': 0.3,
#  'keras__epochs': 128,
#  'keras__hidden_layers': 4,
#  'keras__hidden_neurons': 100,
#  'keras__init_mode': 'uniform',
#  'keras__learn_rate': 0.01,
#  'keras__momentum': 0.0,
#  'keras__neurons': 10,
#  'keras__optimizer': 'Adam',
#  'keras__weight_constraint': 2}
# {'accuracy': 0.865383978814962,
#  'precision': 0.803599569556106,
#  'recall': 0.9702002648129758}
