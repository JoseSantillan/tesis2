# %%
import sys
sys.path.append('./libs')
import util_modelo_final
import importlib

importlib.reload(util_modelo_final)

tuned_parameters = [{'keras__batch_size': [2**10], 'keras__epochs': [2**10], 'keras__optimizer': ['Adam'], 'keras__learn_rate': [0.01], 'keras__momentum': [0], 'keras__init_mode': ['uniform'], 'keras__activation': ['relu'], 'keras__activation2': ['softmax'], 'keras__dropout_rate': [0.0], 'keras__weight_constraint': [1], 'keras__neurons': [10]}]
tesis2 = util_modelo_final.Tesis2(carpeta_base="real",verbose=100,tuned_parameters=tuned_parameters)
# Out:
# Using TensorFlow backend.

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '-1'

if (tesis2.verbose > 1): print("*************************************************")
if (tesis2.verbose > 1): print("*************** Generando llaves ****************")
if (tesis2.verbose > 1): print("*************************************************")
# %time tesis2.generar_llaves_clases()
if (tesis2.verbose > 1): print("*************************************************")
if (tesis2.verbose > 1): print("***************** Armando folds *****************")
if (tesis2.verbose > 1): print("*************************************************")
# %time tesis2.armar_folds()
if (tesis2.verbose > 1): print("*************************************************")
if (tesis2.verbose > 1): print("***** Generando modelo cpat para cada fold ******")
if (tesis2.verbose > 1): print("*************************************************")
# %time tesis2.generar_cpats_de_folds()
if (tesis2.verbose > 1): print("*************************************************")
if (tesis2.verbose > 1): print("*** Ejecutando cpat y diamond sobre los folds ***")
if (tesis2.verbose > 1): print("*************************************************")
# %time tesis2.ejecutar_cpat_diamond_folds()
if (tesis2.verbose > 1): print("*************************************************")
if (tesis2.verbose > 1): print("************* Serializando features *************")
if (tesis2.verbose > 1): print("*************************************************")
# %time tesis2.generar_features_folds()
# Out:
# *************************************************
# *************** Generando llaves ****************
# *************************************************
# CPU times: user 7.94 ms, sys: 4.24 ms, total: 12.2 ms
# Wall time: 677 ms
# *************************************************
# ***************** Armando folds *****************
# *************************************************
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   25.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:   25.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:   43.2s
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:   43.4s
# ...
