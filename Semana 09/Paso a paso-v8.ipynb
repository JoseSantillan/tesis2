# %%
import time
import os
import shutil

start = time.time()
cantidad_especies = 30
cantidad_transcritos = 4208
n_jobs = 4
verbose = 0
carpeta_base = "./real"
carpeta_data_base = carpeta_base + "/data"
carpeta_fold_base = carpeta_base + "/folds"
carpeta_modelo_base = carpeta_base + "/modelos_referenciales"
tuned_parameters = [{'svc__kernel': ['rbf'], 'svc__gamma': [1e-3], 'svc__C': [0.1,0.5,0.9,2]}]
score = ['accuracy','precision','recall']

#cantidad_especies = 3
#cantidad_transcritos = 400
#carpeta_base = "./prueba"
verbose = 100

# %%
#if os.path.isdir(carpeta_base):
#    shutil.rmtree(carpeta_base)
#os.mkdir(carpeta_base)

# %%
#Generación de archivos fasta para las 30 especies
import sys
sys.path.append('./libs')
import util_bd, util_fasta
import os
import shutil
from sklearn.externals.joblib import Parallel, delayed, dump

def carpeta_data():
    return carpeta_data_base

def carpeta_fold():
    return carpeta_fold_base

def carpeta_modelo():
    return carpeta_modelo_base

def obtener_especies():
    query = "SELECT * FROM (SELECT CONVERT(@row_number:=@row_number + 1, UNSIGNED) AS orden, m.id_especie, m.especie FROM especies_seleccionadas s JOIN maestra_especies m ON s.especie = m.especie, (SELECT @row_number:=0) AS rn ORDER BY m.id_especie) a ORDER BY 1 LIMIT " + str(cantidad_especies)
    return util_bd.resultados_query(query)
        
def generar_fasta_especie(row_especie):
    os.mkdir(carpeta_data() + "/clase_" + str(row_especie[0]))
    # lncRNA
    query = "SELECT cod_secuencia, secuencia FROM secuencias WHERE flg_pct = 0 AND flg_seleccionado = 1 AND id_especie = " + str(row_especie[1]) + " ORDER BY cod_secuencia LIMIT " + str(cantidad_transcritos)
    secuencias = util_bd.resultados_query(query)
    util_fasta.generar_fasta(secuencias, carpeta_data() + "/clase_" + str(row_especie[0]) + "/lncRNA.fa")
    # PCT
    query = "SELECT cod_secuencia, secuencia FROM secuencias WHERE flg_pct = 1 AND flg_seleccionado = 1 AND id_especie = " + str(row_especie[1]) + " ORDER BY cod_secuencia LIMIT " + str(cantidad_transcritos)
    secuencias = util_bd.resultados_query(query)
    util_fasta.generar_fasta(secuencias, carpeta_data() + "/clase_" + str(row_especie[0]) + "/PCT.fa")
    # CDS
    query = "SELECT f.cod_secuencia, cds.coding FROM secuencias_CDS cds JOIN secuencias_features f ON cds.id_especie = f.id_especie AND cds.cod_secuencia = f.cod_secuencia WHERE f.flg_pct = 1 AND f.flg_seleccionado = 1 AND f.id_especie = " + str(row_especie[1]) + " ORDER BY f.cod_secuencia LIMIT " + str(cantidad_transcritos)
    secuencias = util_bd.resultados_query(query)
    util_fasta.generar_fasta(secuencias, carpeta_data() + "/clase_" + str(row_especie[0]) + "/CDS.fa")

#if os.path.isdir(carpeta_data()):
#    shutil.rmtree(carpeta_data())
#os.mkdir(carpeta_data())

#%time dump(obtener_especies(), carpeta_data() + "/info_clases.bin")
#%time Parallel(n_jobs=n_jobs, verbose=verbose)(delayed(generar_fasta_especie)(row_especie) for row_especie in #obtener_especies())

print("Proceso finalizado")
# Out:
# Proceso finalizado

# %%
#Construir llave de folds
import os
import sys
sys.path.append('./libs')
import util_fasta
import hashlib
from sklearn.externals.joblib import dump, load
import importlib

importlib.reload(util_fasta) 

def folder_clase(num_clase):
    return carpeta_data() + "/clase_" + str(num_clase)

def archivo_clase(num_clase, tipo):
    return folder_clase(num_clase) + "/" + tipo + ".fa"

def obtener_num_clases():
    num_clases = 0
    if not os.path.isfile(carpeta_data() + "/num_clases.bin"):
        while os.path.isdir(folder_clase(num_clases + 1)):
            num_clases = num_clases + 1
        dump(num_clases, carpeta_data() + "/num_clases.bin")
    num_clases = load(carpeta_data() + "/num_clases.bin")
    return num_clases

def iterador_clases():
    return range(1, obtener_num_clases() + 1)

def obtener_primera_secuencia(num_clase):
    secuencias = util_fasta.leer_fasta(archivo_clase(num_clase, "lncRNA"), 1)
    return list(secuencias.keys())[0]

def obtener_todas_las_secuencias():
    return {num_clase : obtener_primera_secuencia(num_clase) for num_clase in iterador_clases()}

def generar_llaves_clases():
    secuencias = obtener_todas_las_secuencias()
    llaves = {num_clase : "" for num_clase in secuencias.keys()}
    llaves[0] = "" #llave cero corresponde a todo el universo
    for i_clase in iterador_clases():
        llaves[0] += secuencias[i_clase]
        for j_clase in iterador_clases():
            if (i_clase != j_clase):
                llaves[j_clase] += secuencias[i_clase]
    llaves[0] = hashlib.sha224(llaves[0].encode()).hexdigest()
    for i_clase in iterador_clases():
        llaves[i_clase] = hashlib.sha224(llaves[i_clase].encode()).hexdigest()
    dump(llaves, carpeta_data() + "/llaves_clases.bin")

def obtener_llaves_clases():
    return load(carpeta_data() + "/llaves_clases.bin")

#%time generar_llaves_clases()

print("Proceso finalizado")
# Out:
# Proceso finalizado

# %%
#Armando folds (archivos fasta)
import os
import shutil
from sklearn.externals.joblib import Parallel, delayed, load

def cargar_llaves_clases():
    return load(carpeta_data() + "/llaves_clases.bin")

def carpeta_fold_clase(llave):
    return carpeta_fold() + "/fold_clase_" + str(llave)

def archivo_fold_clase(llave, tipoTrainTest, tipoRNA):
    return carpeta_fold_clase(llave) + "/" + tipoTrainTest + "/" + tipoRNA + ".fa"

def armar_fold_final(tipo):
    llave = obtener_llaves_clases()[0]
    if not os.path.isdir(carpeta_fold_clase(llave)):
        os.mkdir(carpeta_fold_clase(llave))
    if not os.path.isdir(carpeta_fold_clase(llave) + "/train"):
        os.mkdir(carpeta_fold_clase(llave) + "/train")
    with open(archivo_fold_clase(llave, "train", tipo), "w+") as outfile:
        for num_clase in iterador_clases():
            with open(archivo_clase(num_clase, tipo), "r") as infile:
                for inline in infile:
                    outfile.write(inline)
    
def armar_fold_clase(num_clase):
    llave = obtener_llaves_clases()[num_clase]
    os.mkdir(carpeta_fold_clase(llave))
    os.mkdir(carpeta_fold_clase(llave) + "/train")
    for tipo in ["lncRNA", "PCT", "CDS"]:
        with open(archivo_fold_clase(llave, "train", tipo), "w+") as outfile:
            for j_num_clase in iterador_clases():
                if num_clase != j_num_clase:
                    with open(archivo_clase(j_num_clase, tipo)) as infile:
                        for inline in infile:
                            outfile.write(inline)
    os.mkdir(carpeta_fold_clase(llave) + "/test")
    for tipo in ["lncRNA", "PCT"]:
        with open(archivo_fold_clase(llave, "test", tipo), "w+") as outfile:
            with open(archivo_clase(num_clase, tipo)) as infile:
                for inline in infile:
                    outfile.write(inline)
                    
#if os.path.isdir(carpeta_fold()):
#    shutil.rmtree(carpeta_fold())
#os.mkdir(carpeta_fold())

#%time Parallel(n_jobs=n_jobs, verbose=verbose)(delayed(armar_fold_final)(tipo) for tipo in ["lncRNA", "PCT", "CDS"])
#%time Parallel(n_jobs=n_jobs, verbose=verbose)(delayed(armar_fold_clase)(num_clase) for num_clase in iterador_clases())
    
print("Proceso finalizado")
# Out:
# Proceso finalizado

# %%
#Generando modelos CPAT de los folds
import sys
sys.path.append('./libs')
import util_caracteristicas
import os
import importlib

importlib.reload(util_caracteristicas)

def carpeta_fold_cpat(llave):
    return carpeta_fold_clase(llave) + "/cpat"

def generar_cpat_fold(num_clase):
    llave = obtener_llaves_clases()[num_clase]
    archivo_lncRNA = archivo_fold_clase(llave, "train", "lncRNA")
    archivo_PCT = archivo_fold_clase(llave, "train", "PCT")
    archivo_CDS = archivo_fold_clase(llave, "train", "CDS")
    carpeta_cpat = carpeta_fold_cpat(llave)
    if not os.path.isdir(carpeta_cpat):
        os.mkdir(carpeta_cpat)
    util_caracteristicas.generar_modelo_CPAT(archivo_lncRNA, archivo_PCT, archivo_CDS, carpeta_cpat)
    
def generar_cpat_final():
    llave = obtener_llaves_clases()[0]
    archivo_lncRNA = archivo_fold_clase(llave, "train", "lncRNA")
    archivo_PCT = archivo_fold_clase(llave, "train", "PCT")
    archivo_CDS = archivo_fold_clase(llave, "train", "CDS")
    carpeta_cpat = carpeta_fold_cpat(llave)
    if not os.path.isdir(carpeta_cpat):
        os.mkdir(carpeta_cpat)
    util_caracteristicas.generar_modelo_CPAT(archivo_lncRNA, archivo_PCT, archivo_CDS, carpeta_cpat)

def limpieza_archivos_CDS(num_clase):
    llave = obtener_llaves_clases()[num_clase]
    os.remove(archivo_fold_clase(llave, "train", "CDS"))

#%time generar_cpat_final()
#%time Parallel(n_jobs=n_jobs, verbose=verbose)(delayed(generar_cpat_fold)(num_clase) for num_clase in iterador_clases())
#%time limpieza_archivos_CDS(0)
#%time Parallel(n_jobs=n_jobs, verbose=verbose)(delayed(limpieza_archivos_CDS)(num_clase) for num_clase in iterador_clases())
    
print("Proceso finalizado")
# Out:
# Proceso finalizado

# %%
#Ejecutar cpat y diamond sobre los folds
import os
import sys
sys.path.append('./libs')
import util_caracteristicas
import importlib

importlib.reload(util_caracteristicas)

def ejecutar_cpat_fold(num_clase):
    llave = obtener_llaves_clases()[num_clase]
    archivo_lncRNA = archivo_fold_clase(llave, "train", "lncRNA")
    archivo_PCT = archivo_fold_clase(llave, "train", "PCT")
    carpeta_cpat = carpeta_fold_cpat(llave)
    util_caracteristicas.ejecutar_cpat(archivo_lncRNA, carpeta_cpat, archivo_lncRNA.replace(".fa", ".cpat"))
    os.remove(archivo_lncRNA.replace(".fa", ".cpat") + ".dat")
    os.remove(archivo_lncRNA.replace(".fa", ".cpat") + ".r")
    util_caracteristicas.ejecutar_cpat(archivo_PCT, carpeta_cpat, archivo_PCT.replace(".fa", ".cpat"))
    os.remove(archivo_PCT.replace(".fa", ".cpat") + ".dat")
    os.remove(archivo_PCT.replace(".fa", ".cpat") + ".r")

def ejecutar_cpat_diamond_final():
    llave = obtener_llaves_clases()[0]
    archivo_lncRNA = archivo_fold_clase(llave, "train", "lncRNA")
    archivo_PCT = archivo_fold_clase(llave, "train", "PCT")
    diamond_db = "./feature_engine/Diamond_BD/uniprot-viridiplantae-reviewed.dmnd"
    carpeta_cpat = carpeta_fold_cpat(llave)
    util_caracteristicas.ejecutar_diamond(archivo_lncRNA, diamond_db, archivo_lncRNA.replace(".fa", ".dmnd"))
    util_caracteristicas.ejecutar_diamond(archivo_PCT, diamond_db, archivo_PCT.replace(".fa", ".dmnd"))
    util_caracteristicas.ejecutar_cpat(archivo_lncRNA, carpeta_cpat, archivo_lncRNA.replace(".fa", ".cpat"))
    os.remove(archivo_lncRNA.replace(".fa", ".cpat") + ".dat")
    os.remove(archivo_lncRNA.replace(".fa", ".cpat") + ".r")
    util_caracteristicas.ejecutar_cpat(archivo_PCT, carpeta_cpat, archivo_PCT.replace(".fa", ".cpat"))
    os.remove(archivo_PCT.replace(".fa", ".cpat") + ".dat")
    os.remove(archivo_PCT.replace(".fa", ".cpat") + ".r")

#%time ejecutar_cpat_diamond_final()
#%time Parallel(n_jobs=n_jobs, verbose=verbose)(delayed(ejecutar_cpat_fold)(num_clase) for num_clase in iterador_clases())
    
print("Proceso finalizado")
# Out:
# Proceso finalizado

# %%
#Generar archivo de features por cada fold
import os
import sys
sys.path.append('./libs')
import util_caracteristicas
import importlib

importlib.reload(util_caracteristicas)

def archivo_features_clase(llave, tipoTrainTest, tipoRNA):
    return archivo_fold_clase(llave, tipoTrainTest, tipoRNA).replace(".fa", ".ft")

def generar_features_fold(num_clase):
    llave = obtener_llaves_clases()[num_clase]
    features_base_lncRNA = archivo_features_clase(obtener_llaves_clases()[0], "train", "lncRNA")
    features_base_PCT = archivo_features_clase(obtener_llaves_clases()[0], "train", "PCT")
    for tipo in ["train", "test"]:
        archivo_lncRNA = archivo_fold_clase(llave, tipo, "lncRNA")
        archivo_PCT = archivo_fold_clase(llave, tipo, "PCT")
        archivo_cpat_lncRNA = archivo_fold_clase(llave, "train", "lncRNA").replace(".fa", ".cpat")
        archivo_cpat_PCT = archivo_fold_clase(llave, "train", "PCT").replace(".fa", ".cpat")
        salida_lncRNA = archivo_features_clase(llave, tipo, "lncRNA")
        salida_PCT = archivo_features_clase(llave, tipo, "PCT")
        util_caracteristicas.generar_features(archivo_lncRNA, features_base_lncRNA, archivo_cpat_lncRNA, salida_lncRNA)
        util_caracteristicas.generar_features(archivo_PCT, features_base_PCT, archivo_cpat_PCT, salida_PCT)
    
def generar_features_final():
    llave = obtener_llaves_clases()[0]
    archivo_lncRNA = archivo_fold_clase(llave, "train", "lncRNA")
    archivo_PCT = archivo_fold_clase(llave, "train", "PCT")
    salida_lncRNA = archivo_features_clase(llave, "train", "lncRNA")
    salida_PCT = archivo_features_clase(llave, "train", "PCT")
    util_caracteristicas.generar_features_base(archivo_lncRNA, archivo_lncRNA.replace(".fa", ".cpat"), archivo_lncRNA.replace(".fa", ".dmnd"), salida_lncRNA)
    util_caracteristicas.generar_features_base(archivo_PCT, archivo_PCT.replace(".fa", ".cpat"), archivo_PCT.replace(".fa", ".dmnd"), salida_PCT)

#%time generar_features_final()
#%time Parallel(n_jobs=n_jobs, verbose=verbose)(delayed(generar_features_fold)(num_clase) for num_clase in iterador_clases())
    
print("Proceso finalizado")
# Out:
# Proceso finalizado

# %%
#Generar modelo final
from sklearn.pipeline import Pipeline
from sklearn.svm import SVC
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import LeaveOneGroupOut, GridSearchCV
from sklearn.externals.joblib import dump, load
import hashlib
import util_fasta
import os
from sklearn.preprocessing import RobustScaler
import importlib

importlib.reload(util_fasta)

def obtener_data_entrenamiento():
    llave = obtener_llaves_clases()[0]
    codigos_lncRNA = util_fasta.leer_fasta_list(archivo_fold_clase(llave, "train", "lncRNA"))
    codigos_PCT = util_fasta.leer_fasta_list(archivo_fold_clase(llave, "train", "PCT"))
    
    codigos_lncRNA = [(x[0],"") for x in codigos_lncRNA]
    codigos_PCT = [(x[0],"") for x in codigos_PCT]
    
    y = ([1] * len(codigos_lncRNA)) + ([0] * len(codigos_PCT))
    groups = list()
    for _ in range(2):
        for num_clase in iterador_clases():
            groups += ([num_clase] * (cantidad_transcritos))
    return codigos_lncRNA + codigos_PCT, y, groups

class GeneradorFeatures(BaseEstimator, TransformerMixin):
    def __init__(self, cantidad_transcritos=None, num_clases=None):
        if cantidad_transcritos is None:
            return
        self.cantidad_transcritos = cantidad_transcritos
        self.num_clases = num_clases
        
    def fit(self, X, y=None):
        self._llave_fold = self.obtener_llave_fold(X)
        return self
        
    def transform(self, X):
        return self.obtener_features_pre_calculados(X)
    
    def obtener_llave_fold(self, X):
        cod_secuencias = ""
        cod_secuencias2 = ""
        num_transcritos = len(X)
        num_transcritos_por_grupo = self.cantidad_transcritos
        for i in range(num_transcritos//(num_transcritos_por_grupo*2)):
            cod_secuencias += X[i * num_transcritos_por_grupo][0]
            cod_secuencias2 += X[i * num_transcritos_por_grupo][0] + "*****"
        llave = hashlib.sha224(cod_secuencias.encode()).hexdigest()
        return llave
    
    def obtener_features_pre_calculados(self, X):
        llave = self._llave_fold
        tipo = "train"
        if os.path.isfile(archivo_fold_clase(llave, "test", "lncRNA")):
            secuencias = util_fasta.leer_fasta(archivo_fold_clase(llave, "test", "lncRNA"), 1)
            if list(secuencias.keys())[0] == X[0][0]:
                tipo = "test"
        features = list(load(archivo_features_clase(llave, tipo, "lncRNA")).values())
        features += list(load(archivo_features_clase(llave, tipo, "PCT")).values())
        return [list(x.values()) for x in features]

def generar_modelo_final(tuned_parameters):
    print("Obteniendo data")
    X_train, y_train, groups = obtener_data_entrenamiento()
    svm_pipeline = Pipeline(steps=[('features', GeneradorFeatures(cantidad_transcritos, obtener_num_clases())), ('scaler', RobustScaler()), ('svc', SVC())])
    logo = LeaveOneGroupOut()
    print("Grid seach")
    clf = GridSearchCV(svm_pipeline, tuned_parameters, cv=logo, scoring=score, n_jobs=n_jobs, refit="accuracy", return_train_score = True, verbose=verbose)
    print("Realizando fit final")
    clf.fit(X_train, y_train, groups) #requerido por LeaveOneGroupOut
    resultado = {
        "accuracy" : clf.cv_results_['mean_test_accuracy'][clf.best_index_],
        "precision" : clf.cv_results_['mean_test_precision'][clf.best_index_],
        "recall" : clf.cv_results_['mean_test_recall'][clf.best_index_]
    }
    dump(resultado, carpeta_modelo() + "/resultado.bin")
    dump(clf.best_params_, carpeta_modelo() + "/params.bin")
    dump(clf.cv_results_, carpeta_modelo() + "/cv_results.bin")
    dump(clf.best_estimator_, carpeta_modelo() + "/modelo.plk")
    
if not os.path.isdir(carpeta_modelo()):
    #shutil.rmtree(carpeta_modelo())
    os.mkdir(carpeta_modelo())

# %time generar_modelo_final(tuned_parameters)
    
print("Proceso finalizado")
# Out:
# Obteniendo data
# Grid seach
# Realizando fit final
# Fitting 30 folds for each of 4 candidates, totalling 120 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-e32a3e2781d547508cf3bc9bec8c3e0a.pkl
# Pickling array (shape=(8416,), dtype=int64).
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-420ff8394580416e943c5a5ab0c7dfd2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-f8ab1f9dcbb64d7caec02b1abc16f8a5.pkl
# Pickling array (shape=(8416,), dtype=int64).
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-624cdf27687f45bfa9dc9e6677a01d60.pkl
# Pickling array (shape=(8416,), dtype=int64).
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-d92b65f03a8248e4a1388680083e9ce1.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done   1 tasks      | elapsed: 137.9min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-52ec73793d34448a94f52eb459cbb8a2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done   2 tasks      | elapsed: 139.6min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-c969db5bfacb4d01aaa2b2915de9528d.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done   3 tasks      | elapsed: 149.4min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-e2585f397d6a4175a9fc10ea11835698.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done   4 tasks      | elapsed: 170.0min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-38258f8658a04b5b9d4c3bb66993d44e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed: 277.7min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-2447125348184108be4b56a986927d70.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done   6 tasks      | elapsed: 296.0min
# /home/jose/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/externals/loky/process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-cb6ba6944689431c9661de138eb1ff1c.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done   7 tasks      | elapsed: 317.7min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-70b20b3049774f3a919273ede4231a91.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done   8 tasks      | elapsed: 331.4min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-69c8634ef3464159aea1c795e27c459e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done   9 tasks      | elapsed: 418.7min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-beb6414ab29c4eeaab1a9528595c0df3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed: 471.8min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-036da9df0ed5408b8b0a22f2ade5686c.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  11 tasks      | elapsed: 481.6min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-7e8e1745f3714e02bdeafe867a6b1862.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed: 498.0min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-6471653c0d07432ba63bdb706fbf93b2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  13 tasks      | elapsed: 592.2min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-8c475952e0e446c6a15ce7ecaed55c31.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  14 tasks      | elapsed: 609.2min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-756148a75f83415a8b086f08c1967453.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  15 tasks      | elapsed: 635.7min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-c321438a0fcb4c1382aeb302cec809f3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  16 tasks      | elapsed: 648.0min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-a7914f5237a14b6eae1bf594f2373013.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed: 727.0min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-60c6d0d43f7845a78558373bcf4dfb86.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  18 tasks      | elapsed: 769.9min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-84bfeb75e2394b6a82ec618faa06fe93.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  19 tasks      | elapsed: 797.0min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-2251eada654b4f09a989900971123dde.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  20 tasks      | elapsed: 814.2min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-56e8de5f0777410ea6b00a29156883ae.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  21 tasks      | elapsed: 893.8min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-3f09cf03f68e4ee192e1d2c8e819e205.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  22 tasks      | elapsed: 932.8min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-307ffe7a8e034b459f8b2c28f8e16ef3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  23 tasks      | elapsed: 957.2min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-587e96fea0df496b89764eac8563fc0e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed: 963.4min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-fabb2a623d1640eea312b835df22a5d8.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  25 tasks      | elapsed: 1059.5min
# Memmapping (shape=(244064,), dtype=int64) to new file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-8df81e2dbd2b4c0881b16ab3b8bd21cb.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  26 tasks      | elapsed: 1070.2min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-e32a3e2781d547508cf3bc9bec8c3e0a.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  27 tasks      | elapsed: 1102.5min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-420ff8394580416e943c5a5ab0c7dfd2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  28 tasks      | elapsed: 1103.3min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-f8ab1f9dcbb64d7caec02b1abc16f8a5.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  29 tasks      | elapsed: 1226.8min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-624cdf27687f45bfa9dc9e6677a01d60.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  30 tasks      | elapsed: 1231.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-d92b65f03a8248e4a1388680083e9ce1.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  31 tasks      | elapsed: 1245.4min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-52ec73793d34448a94f52eb459cbb8a2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  32 tasks      | elapsed: 1250.2min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-c969db5bfacb4d01aaa2b2915de9528d.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed: 1377.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-e2585f397d6a4175a9fc10ea11835698.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  34 tasks      | elapsed: 1381.2min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-38258f8658a04b5b9d4c3bb66993d44e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  35 tasks      | elapsed: 1387.7min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-2447125348184108be4b56a986927d70.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  36 tasks      | elapsed: 1391.3min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-cb6ba6944689431c9661de138eb1ff1c.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  37 tasks      | elapsed: 1510.8min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-70b20b3049774f3a919273ede4231a91.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  38 tasks      | elapsed: 1516.2min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-69c8634ef3464159aea1c795e27c459e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  39 tasks      | elapsed: 1545.6min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-beb6414ab29c4eeaab1a9528595c0df3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  40 tasks      | elapsed: 1549.9min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-036da9df0ed5408b8b0a22f2ade5686c.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  41 tasks      | elapsed: 1654.7min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-7e8e1745f3714e02bdeafe867a6b1862.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed: 1661.8min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-6471653c0d07432ba63bdb706fbf93b2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  43 tasks      | elapsed: 1676.8min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-8c475952e0e446c6a15ce7ecaed55c31.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  44 tasks      | elapsed: 1709.9min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-756148a75f83415a8b086f08c1967453.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  45 tasks      | elapsed: 1799.8min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-c321438a0fcb4c1382aeb302cec809f3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  46 tasks      | elapsed: 1803.0min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-a7914f5237a14b6eae1bf594f2373013.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  47 tasks      | elapsed: 1812.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-60c6d0d43f7845a78558373bcf4dfb86.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  48 tasks      | elapsed: 1848.5min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-84bfeb75e2394b6a82ec618faa06fe93.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  49 tasks      | elapsed: 1942.7min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-2251eada654b4f09a989900971123dde.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  50 tasks      | elapsed: 1947.5min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-56e8de5f0777410ea6b00a29156883ae.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  51 tasks      | elapsed: 1975.3min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-3f09cf03f68e4ee192e1d2c8e819e205.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  52 tasks      | elapsed: 2000.3min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-307ffe7a8e034b459f8b2c28f8e16ef3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  53 tasks      | elapsed: 2067.6min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-587e96fea0df496b89764eac8563fc0e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  54 tasks      | elapsed: 2078.8min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-fabb2a623d1640eea312b835df22a5d8.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  55 tasks      | elapsed: 2111.9min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-8df81e2dbd2b4c0881b16ab3b8bd21cb.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  56 tasks      | elapsed: 2145.4min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-e32a3e2781d547508cf3bc9bec8c3e0a.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  57 tasks      | elapsed: 2211.9min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-420ff8394580416e943c5a5ab0c7dfd2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  58 tasks      | elapsed: 2215.5min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-f8ab1f9dcbb64d7caec02b1abc16f8a5.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  59 tasks      | elapsed: 2273.3min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-624cdf27687f45bfa9dc9e6677a01d60.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  60 tasks      | elapsed: 2277.4min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-d92b65f03a8248e4a1388680083e9ce1.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  61 tasks      | elapsed: 2352.7min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-52ec73793d34448a94f52eb459cbb8a2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  62 tasks      | elapsed: 2358.6min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-c969db5bfacb4d01aaa2b2915de9528d.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  63 tasks      | elapsed: 2409.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-e2585f397d6a4175a9fc10ea11835698.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed: 2439.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-38258f8658a04b5b9d4c3bb66993d44e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  65 tasks      | elapsed: 2481.9min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-2447125348184108be4b56a986927d70.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  66 tasks      | elapsed: 2483.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-cb6ba6944689431c9661de138eb1ff1c.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  67 tasks      | elapsed: 2532.9min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-70b20b3049774f3a919273ede4231a91.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  68 tasks      | elapsed: 2592.0min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-69c8634ef3464159aea1c795e27c459e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  69 tasks      | elapsed: 2635.7min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-beb6414ab29c4eeaab1a9528595c0df3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  70 tasks      | elapsed: 2642.8min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-036da9df0ed5408b8b0a22f2ade5686c.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  71 tasks      | elapsed: 2693.8min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-7e8e1745f3714e02bdeafe867a6b1862.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  72 tasks      | elapsed: 2734.9min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-6471653c0d07432ba63bdb706fbf93b2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  73 tasks      | elapsed: 2762.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-8c475952e0e446c6a15ce7ecaed55c31.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  74 tasks      | elapsed: 2768.8min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-756148a75f83415a8b086f08c1967453.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  75 tasks      | elapsed: 2829.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-c321438a0fcb4c1382aeb302cec809f3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  76 tasks      | elapsed: 2879.6min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-a7914f5237a14b6eae1bf594f2373013.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  77 tasks      | elapsed: 2899.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-60c6d0d43f7845a78558373bcf4dfb86.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  78 tasks      | elapsed: 2912.0min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-84bfeb75e2394b6a82ec618faa06fe93.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  79 tasks      | elapsed: 2995.7min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-2251eada654b4f09a989900971123dde.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  80 tasks      | elapsed: 3002.5min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-56e8de5f0777410ea6b00a29156883ae.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  81 tasks      | elapsed: 3053.3min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-3f09cf03f68e4ee192e1d2c8e819e205.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  82 tasks      | elapsed: 3056.0min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-307ffe7a8e034b459f8b2c28f8e16ef3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  83 tasks      | elapsed: 3136.8min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-587e96fea0df496b89764eac8563fc0e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  84 tasks      | elapsed: 3144.8min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-fabb2a623d1640eea312b835df22a5d8.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  85 tasks      | elapsed: 3196.4min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-8df81e2dbd2b4c0881b16ab3b8bd21cb.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  86 tasks      | elapsed: 3235.5min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-e32a3e2781d547508cf3bc9bec8c3e0a.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  87 tasks      | elapsed: 3268.9min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-420ff8394580416e943c5a5ab0c7dfd2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  88 tasks      | elapsed: 3282.2min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-f8ab1f9dcbb64d7caec02b1abc16f8a5.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  89 tasks      | elapsed: 3332.9min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-624cdf27687f45bfa9dc9e6677a01d60.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  90 tasks      | elapsed: 3361.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-d92b65f03a8248e4a1388680083e9ce1.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  91 tasks      | elapsed: 3393.5min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-52ec73793d34448a94f52eb459cbb8a2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  92 tasks      | elapsed: 3414.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-c969db5bfacb4d01aaa2b2915de9528d.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  93 tasks      | elapsed: 3488.4min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-e2585f397d6a4175a9fc10ea11835698.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  94 tasks      | elapsed: 3515.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-38258f8658a04b5b9d4c3bb66993d44e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  95 tasks      | elapsed: 3516.0min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-2447125348184108be4b56a986927d70.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  96 tasks      | elapsed: 3559.3min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-cb6ba6944689431c9661de138eb1ff1c.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  97 tasks      | elapsed: 3614.7min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-70b20b3049774f3a919273ede4231a91.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  98 tasks      | elapsed: 3658.4min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-69c8634ef3464159aea1c795e27c459e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done  99 tasks      | elapsed: 3666.0min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-beb6414ab29c4eeaab1a9528595c0df3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 100 tasks      | elapsed: 3682.0min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-036da9df0ed5408b8b0a22f2ade5686c.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 101 tasks      | elapsed: 3769.5min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-7e8e1745f3714e02bdeafe867a6b1862.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 102 tasks      | elapsed: 3807.9min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-6471653c0d07432ba63bdb706fbf93b2.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 103 tasks      | elapsed: 3809.7min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-8c475952e0e446c6a15ce7ecaed55c31.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 104 tasks      | elapsed: 3817.4min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-756148a75f83415a8b086f08c1967453.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 105 tasks      | elapsed: 3889.1min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-c321438a0fcb4c1382aeb302cec809f3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 106 tasks      | elapsed: 3930.5min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-a7914f5237a14b6eae1bf594f2373013.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 107 tasks      | elapsed: 3959.5min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-60c6d0d43f7845a78558373bcf4dfb86.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 108 tasks      | elapsed: 3977.4min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-84bfeb75e2394b6a82ec618faa06fe93.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 109 tasks      | elapsed: 4025.2min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-2251eada654b4f09a989900971123dde.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 110 tasks      | elapsed: 4063.4min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-56e8de5f0777410ea6b00a29156883ae.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 111 tasks      | elapsed: 4106.7min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-3f09cf03f68e4ee192e1d2c8e819e205.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 112 tasks      | elapsed: 4136.9min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-307ffe7a8e034b459f8b2c28f8e16ef3.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 113 tasks      | elapsed: 4159.3min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-587e96fea0df496b89764eac8563fc0e.pkl
# Pickling array (shape=(8416,), dtype=int64).
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-fabb2a623d1640eea312b835df22a5d8.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 115 out of 120 | elapsed: 4244.1min remaining: 184.5min
# Memmapping (shape=(244064,), dtype=int64) to old file /dev/shm/joblib_memmapping_folder_3947_4115306362/3947-140607410176240-8df81e2dbd2b4c0881b16ab3b8bd21cb.pkl
# Pickling array (shape=(8416,), dtype=int64).
# [Parallel(n_jobs=4)]: Done 117 out of 120 | elapsed: 4308.3min remaining: 110.5min
# [Parallel(n_jobs=4)]: Done 120 out of 120 | elapsed: 4375.4min finished
# CPU times: user 54min 1s, sys: 7.64 s, total: 54min 9s
# Wall time: 3d 1h 38min 34s
# Proceso finalizado

# %%
import shutil
from sklearn.externals.joblib import Parallel, delayed

def limpieza_archivos_finales_fasta_ruta(llave):
    shutil.rmtree(carpeta_fold_clase(llave))
    
def limpieza_archivos_finales_fasta(num_clase):
    llave = obtener_llaves_clases()[num_clase]
    if num_clase == 0:
        shutil.rmtree(carpeta_fold_clase(llave) + "/train")
    else:
        limpieza_archivos_finales_fasta_ruta(llave)
        
# %time limpieza_archivos_finales_fasta(0)
# %time Parallel(n_jobs=n_jobs, verbose=verbose)(delayed(limpieza_archivos_finales_fasta)(num_clase) for num_clase in iterador_clases())
    
print("Proceso finalizado")
# Out:
# CPU times: user 4.13 ms, sys: 432 µs, total: 4.56 ms
# Wall time: 603 ms
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done   1 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=4)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done   4 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done   6 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=4)]: Done   7 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done   8 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=4)]: Done   9 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done  11 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=4)]: Done  12 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=4)]: Done  13 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  14 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  15 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=4)]: Done  16 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done  18 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done  19 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done  20 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=4)]: Done  21 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done  22 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done  23 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=4)]: Done  24 out of  30 | elapsed:    2.2s remaining:    0.6s
# [Parallel(n_jobs=4)]: Done  25 out of  30 | elapsed:    2.4s remaining:    0.5s
# [Parallel(n_jobs=4)]: Done  26 out of  30 | elapsed:    2.4s remaining:    0.4s
# [Parallel(n_jobs=4)]: Done  27 out of  30 | elapsed:    2.4s remaining:    0.3s
# [Parallel(n_jobs=4)]: Done  28 out of  30 | elapsed:    2.4s remaining:    0.2s
# [Parallel(n_jobs=4)]: Done  30 out of  30 | elapsed:    2.5s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done  30 out of  30 | elapsed:    2.5s finished
# CPU times: user 124 ms, sys: 35.4 ms, total: 159 ms
# Wall time: 2.52 s
# Proceso finalizado

# %%
display(load(carpeta_modelo() + "/cv_results.bin"))
display(load(carpeta_modelo() + "/params.bin"))
display(load(carpeta_modelo() + "/resultado.bin"))
# Out:
# {'mean_fit_time': array([4421.92530204, 4139.52458765, 4166.76457089, 4081.10332456]),
#  'std_fit_time': array([798.9039062 , 657.16957961, 855.20227829, 799.15157534]),
#  'mean_score_time': array([161.42517904, 147.28482095, 147.1550959 , 141.79934688]),
#  'std_score_time': array([ 4.208279  ,  5.2680847 ,  3.70655693, 10.9422552 ]),
#  'param_svc__C': masked_array(data=[0.1, 0.5, 0.9, 2],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_svc__gamma': masked_array(data=[0.001, 0.001, 0.001, 0.001],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_svc__kernel': masked_array(data=['rbf', 'rbf', 'rbf', 'rbf'],
#               mask=[False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'svc__C': 0.1, 'svc__gamma': 0.001, 'svc__kernel': 'rbf'},
#   {'svc__C': 0.5, 'svc__gamma': 0.001, 'svc__kernel': 'rbf'},
#   {'svc__C': 0.9, 'svc__gamma': 0.001, 'svc__kernel': 'rbf'},
#   {'svc__C': 2, 'svc__gamma': 0.001, 'svc__kernel': 'rbf'}],
#  'split0_test_accuracy': array([0.74726711, 0.78065589, 0.78826046, 0.79039924]),
#  'split1_test_accuracy': array([0.85765209, 0.84838403, 0.84980989, 0.85194867]),
#  'split2_test_accuracy': array([0.902923  , 0.90636882, 0.9079135 , 0.90922053]),
#  'split3_test_accuracy': array([0.88129753, 0.89258555, 0.89365494, 0.89436787]),
#  'split4_test_accuracy': array([0.83412548, 0.83388783, 0.83507605, 0.83721483]),
#  'split5_test_accuracy': array([0.82723384, 0.82557034, 0.8269962 , 0.83032319]),
#  'split6_test_accuracy': array([0.8677519 , 0.86145437, 0.86145437, 0.86264259]),
#  'split7_test_accuracy': array([0.79360741, 0.7940827 , 0.79360741, 0.7940827 ]),
#  'split8_test_accuracy': array([0.84006654, 0.83935361, 0.83935361, 0.83875951]),
#  'split9_test_accuracy': array([0.88498099, 0.90090304, 0.90256654, 0.902923  ]),
#  'split10_test_accuracy': array([0.87428707, 0.89686312, 0.89876426, 0.89995247]),
#  'split11_test_accuracy': array([0.90256654, 0.90007129, 0.90019011, 0.90042776]),
#  'split12_test_accuracy': array([0.89923954, 0.90648764, 0.90815114, 0.91076521]),
#  'split13_test_accuracy': array([0.86490019, 0.86394962, 0.86466255, 0.86573194]),
#  'split14_test_accuracy': array([0.82271863, 0.83685837, 0.83852186, 0.8398289 ]),
#  'split15_test_accuracy': array([0.85480038, 0.85788973, 0.85979087, 0.86204848]),
#  'split16_test_accuracy': array([0.83959125, 0.8420865 , 0.84375   , 0.84660171]),
#  'split17_test_accuracy': array([0.875     , 0.87868346, 0.87999049, 0.88177281]),
#  'split18_test_accuracy': array([0.85979087, 0.86727662, 0.86953422, 0.871673  ]),
#  'split19_test_accuracy': array([0.87096008, 0.88117871, 0.88248574, 0.88545627]),
#  'split20_test_accuracy': array([0.86692015, 0.87713878, 0.87808935, 0.87939639]),
#  'split21_test_accuracy': array([0.87963403, 0.90042776, 0.90316065, 0.9045865 ]),
#  'split22_test_accuracy': array([0.84006654, 0.84089829, 0.84232414, 0.84173004]),
#  'split23_test_accuracy': array([0.86787072, 0.85967205, 0.86133555, 0.86169202]),
#  'split24_test_accuracy': array([0.82580798, 0.83495722, 0.8365019 , 0.83662072]),
#  'split25_test_accuracy': array([0.87713878, 0.88878327, 0.88925856, 0.89020913]),
#  'split26_test_accuracy': array([0.92395437, 0.92965779, 0.93048954, 0.9319154 ]),
#  'split27_test_accuracy': array([0.87262357, 0.8677519 , 0.86870247, 0.86965304]),
#  'split28_test_accuracy': array([0.83673954, 0.85503802, 0.85848384, 0.8599097 ]),
#  'split29_test_accuracy': array([0.88189163, 0.87571293, 0.87595057, 0.87595057]),
#  'mean_test_accuracy': array([0.85911359, 0.86482098, 0.86629436, 0.86759347]),
#  'std_test_accuracy': array([0.03444943, 0.03318842, 0.03278332, 0.0327605 ]),
#  'rank_test_accuracy': array([4, 3, 2, 1], dtype=int32),
#  'split0_train_accuracy': array([0.86361774, 0.87164432, 0.87271371, 0.87375443]),
#  'split1_train_accuracy': array([0.86402747, 0.87030451, 0.87075521, 0.8713739 ]),
#  'split2_train_accuracy': array([0.86115527, 0.86813705, 0.86862053, 0.86942359]),
#  'split3_train_accuracy': array([0.86142569, 0.86895241, 0.86955061, 0.87022666]),
#  'split4_train_accuracy': array([0.86380212, 0.87079618, 0.87134112, 0.87190245]),
#  'split5_train_accuracy': array([0.86424872, 0.87087813, 0.8713821 , 0.87186558]),
#  'split6_train_accuracy': array([0.86318343, 0.86999312, 0.87045201, 0.8710748 ]),
#  'split7_train_accuracy': array([0.86584666, 0.87285302, 0.87338157, 0.87395109]),
#  'split8_train_accuracy': array([0.86440032, 0.87124279, 0.87181641, 0.87253343]),
#  'split9_train_accuracy': array([0.86090124, 0.86861233, 0.86945637, 0.87013652]),
#  'split10_train_accuracy': array([0.86094631, 0.86884588, 0.86968172, 0.87039465]),
#  'split11_train_accuracy': array([0.86196653, 0.86916546, 0.86978825, 0.87050528]),
#  'split12_train_accuracy': array([0.86105284, 0.86798545, 0.8686574 , 0.8691081 ]),
#  'split13_train_accuracy': array([0.86304002, 0.87032909, 0.87080848, 0.87150502]),
#  'split14_train_accuracy': array([0.8629212 , 0.87051347, 0.87128376, 0.87211551]),
#  'split15_train_accuracy': array([0.86276141, 0.86982923, 0.87040694, 0.87096008]),
#  'split16_train_accuracy': array([0.86354399, 0.87041923, 0.87093959, 0.87151731]),
#  'split17_train_accuracy': array([0.86230661, 0.86917776, 0.869862  , 0.87041514]),
#  'split18_train_accuracy': array([0.86222466, 0.86939082, 0.87005458, 0.87056264]),
#  'split19_train_accuracy': array([0.86132736, 0.86902206, 0.86999312, 0.87088223]),
#  'split20_train_accuracy': array([0.86185591, 0.86940311, 0.87013652, 0.87075931]),
#  'split21_train_accuracy': array([0.86046283, 0.86825177, 0.86917366, 0.87005048]),
#  'split22_train_accuracy': array([0.86403976, 0.8710789 , 0.87161154, 0.87240642]),
#  'split23_train_accuracy': array([0.86376524, 0.8700218 , 0.87038236, 0.87102154]),
#  'split24_train_accuracy': array([0.86308509, 0.87078799, 0.87155009, 0.87210732]),
#  'split25_train_accuracy': array([0.86182723, 0.86920234, 0.86984971, 0.8704725 ]),
#  'split26_train_accuracy': array([0.860512  , 0.86732169, 0.86789531, 0.86871886]),
#  'split27_train_accuracy': array([0.86291301, 0.8697186 , 0.87014881, 0.87082077]),
#  'split28_train_accuracy': array([0.86048741, 0.86886227, 0.869862  , 0.8707798 ]),
#  'split29_train_accuracy': array([0.86304822, 0.86978415, 0.87019388, 0.87101744]),
#  'mean_train_accuracy': array([0.86255654, 0.86975083, 0.87039165, 0.87107876]),
#  'std_train_accuracy': array([0.00135094, 0.00117774, 0.00115586, 0.00115805]),
#  'split0_test_precision': array([0.70665343, 0.71854182, 0.72175503, 0.72258652]),
#  'split1_test_precision': array([0.7902044 , 0.77881324, 0.78080885, 0.78393405]),
#  'split2_test_precision': array([0.84850976, 0.85286835, 0.85560389, 0.85785536]),
#  'split3_test_precision': array([0.83503863, 0.84720471, 0.84925153, 0.85077151]),
#  'split4_test_precision': array([0.77184841, 0.76823215, 0.76990812, 0.77298961]),
#  'split5_test_precision': array([0.76583012, 0.76025836, 0.76209524, 0.76618154]),
#  'split6_test_precision': array([0.81979748, 0.81309181, 0.81464626, 0.81778426]),
#  'split7_test_precision': array([0.73439575, 0.7353109 , 0.73645933, 0.73848526]),
#  'split8_test_precision': array([0.78359096, 0.784689  , 0.7853717 , 0.78722547]),
#  'split9_test_precision': array([0.86502929, 0.87109547, 0.87263528, 0.87453059]),
#  'split10_test_precision': array([0.86781878, 0.87697517, 0.87758776, 0.88076923]),
#  'split11_test_precision': array([0.87444739, 0.87536232, 0.8765653 , 0.87814183]),
#  'split12_test_precision': array([0.84008097, 0.85144853, 0.85375901, 0.85779342]),
#  'split13_test_precision': array([0.82943574, 0.83214053, 0.83424091, 0.83720421]),
#  'split14_test_precision': array([0.75555137, 0.76071363, 0.76238718, 0.76383764]),
#  'split15_test_precision': array([0.78481496, 0.79039722, 0.79341085, 0.79668939]),
#  'split16_test_precision': array([0.76210565, 0.76495491, 0.76712835, 0.7706439 ]),
#  'split17_test_precision': array([0.80989788, 0.81812737, 0.82056937, 0.82356495]),
#  'split18_test_precision': array([0.79003831, 0.800272  , 0.80311891, 0.80642633]),
#  'split19_test_precision': array([0.81058496, 0.82003192, 0.82183563, 0.82701613]),
#  'split20_test_precision': array([0.81166734, 0.81995968, 0.82128433, 0.82363673]),
#  'split21_test_precision': array([0.84841876, 0.85503582, 0.85738361, 0.85925301]),
#  'split22_test_precision': array([0.77689628, 0.78077902, 0.78328417, 0.78441456]),
#  'split23_test_precision': array([0.80592885, 0.79659024, 0.79925212, 0.80090945]),
#  'split24_test_precision': array([0.79009733, 0.79580273, 0.79860818, 0.80131887]),
#  'split25_test_precision': array([0.83340336, 0.84749363, 0.84895611, 0.8508547 ]),
#  'split26_test_precision': array([0.87073982, 0.88015139, 0.88177028, 0.88416825]),
#  'split27_test_precision': array([0.80963665, 0.80325299, 0.80499312, 0.80747183]),
#  'split28_test_precision': array([0.85927992, 0.86743728, 0.86927785, 0.87220447]),
#  'split29_test_precision': array([0.8336794 , 0.82828073, 0.82972072, 0.83096234]),
#  'mean_test_precision': array([0.80951407, 0.8131771 , 0.8151223 , 0.81765418]),
#  'std_test_precision': array([0.04139398, 0.04315657, 0.04298958, 0.04304725]),
#  'rank_test_precision': array([4, 3, 2, 1], dtype=int32),
#  'split0_train_precision': array([0.82405609, 0.82829636, 0.82786212, 0.82767688]),
#  'split1_train_precision': array([0.81870032, 0.82134629, 0.8218381 , 0.82236828]),
#  'split2_train_precision': array([0.81734459, 0.8196404 , 0.81962356, 0.820147  ]),
#  'split3_train_precision': array([0.81920029, 0.82165055, 0.82157017, 0.82177985]),
#  'split4_train_precision': array([0.81978549, 0.82254822, 0.82293708, 0.82336302]),
#  'split5_train_precision': array([0.81936601, 0.82235296, 0.82282548, 0.82320891]),
#  'split6_train_precision': array([0.81868385, 0.82129997, 0.82168932, 0.8222072 ]),
#  'split7_train_precision': array([0.82263077, 0.8256513 , 0.8260546 , 0.82645148]),
#  'split8_train_precision': array([0.82043134, 0.8232155 , 0.82358101, 0.82402247]),
#  'split9_train_precision': array([0.81896795, 0.82185302, 0.82184388, 0.82191244]),
#  'split10_train_precision': array([0.81895466, 0.82207307, 0.82210227, 0.82220812]),
#  'split11_train_precision': array([0.81785146, 0.82065883, 0.82082984, 0.82122127]),
#  'split12_train_precision': array([0.81761822, 0.81982053, 0.82004439, 0.82009864]),
#  'split13_train_precision': array([0.81966823, 0.82230273, 0.82237278, 0.82273002]),
#  'split14_train_precision': array([0.82170148, 0.8246419 , 0.82458038, 0.82476077]),
#  'split15_train_precision': array([0.81978748, 0.82218938, 0.82237738, 0.82249768]),
#  'split16_train_precision': array([0.82040097, 0.82295239, 0.82323286, 0.82347527]),
#  'split17_train_precision': array([0.81898791, 0.82129842, 0.8215339 , 0.8216779 ]),
#  'split18_train_precision': array([0.81956594, 0.82189707, 0.82198344, 0.82199389]),
#  'split19_train_precision': array([0.81909959, 0.82172276, 0.8219644 , 0.82251502]),
#  'split20_train_precision': array([0.82041737, 0.82286459, 0.82283276, 0.8229328 ]),
#  'split21_train_precision': array([0.81892464, 0.82222063, 0.82202748, 0.82211998]),
#  'split22_train_precision': array([0.82059942, 0.82327577, 0.82358734, 0.82408061]),
#  'split23_train_precision': array([0.81853473, 0.82129058, 0.82167232, 0.82216783]),
#  'split24_train_precision': array([0.82092828, 0.82353278, 0.82373941, 0.82368414]),
#  'split25_train_precision': array([0.81962431, 0.82196274, 0.82200264, 0.82210823]),
#  'split26_train_precision': array([0.81669954, 0.8188712 , 0.81890636, 0.81940471]),
#  'split27_train_precision': array([0.81830466, 0.8209725 , 0.82127057, 0.82170736]),
#  'split28_train_precision': array([0.81964164, 0.82371343, 0.82278481, 0.82253856]),
#  'split29_train_precision': array([0.81855375, 0.82112537, 0.821248  , 0.82188713]),
#  'mean_train_precision': array([0.81950103, 0.82224137, 0.82236396, 0.82263158]),
#  'std_train_precision': array([0.00148502, 0.001777  , 0.00171641, 0.00164904]),
#  'split0_test_recall': array([0.84553232, 0.92276616, 0.93821293, 0.94272814]),
#  'split1_test_recall': array([0.97385932, 0.97314639, 0.9726711 , 0.97172053]),
#  'split2_test_recall': array([0.98098859, 0.98217681, 0.98146388, 0.98098859]),
#  'split3_test_recall': array([0.9503327 , 0.95793726, 0.95722433, 0.95651141]),
#  'split4_test_recall': array([0.9486692 , 0.95627376, 0.95579848, 0.95484791]),
#  'split5_test_recall': array([0.94272814, 0.95104563, 0.95080798, 0.95080798]),
#  'split6_test_recall': array([0.94272814, 0.93868821, 0.9358365 , 0.93322243]),
#  'split7_test_recall': array([0.91991445, 0.91896388, 0.91444867, 0.91064639]),
#  'split8_test_recall': array([0.93963878, 0.93536122, 0.93393536, 0.92846958]),
#  'split9_test_recall': array([0.91230989, 0.94106464, 0.94272814, 0.940827  ]),
#  'split10_test_recall': array([0.88307985, 0.92324144, 0.92680608, 0.92514259]),
#  'split11_test_recall': array([0.94011407, 0.93298479, 0.93155894, 0.92989544]),
#  'split12_test_recall': array([0.98621673, 0.98479087, 0.98502852, 0.98479087]),
#  'split13_test_recall': array([0.91872624, 0.9118346 , 0.9101711 , 0.90803232]),
#  'split14_test_recall': array([0.95413498, 0.98288973, 0.98360266, 0.9838403 ]),
#  'split15_test_recall': array([0.9776616 , 0.97409696, 0.97290875, 0.97219582]),
#  'split16_test_recall': array([0.98740494, 0.98764259, 0.9871673 , 0.98692966]),
#  'split17_test_recall': array([0.98003802, 0.97385932, 0.9726711 , 0.97172053]),
#  'split18_test_recall': array([0.98003802, 0.97884981, 0.97908745, 0.97813688]),
#  'split19_test_recall': array([0.96815589, 0.97671103, 0.97671103, 0.97480989]),
#  'split20_test_recall': array([0.95556084, 0.9664924 , 0.9664924 , 0.96554183]),
#  'split21_test_recall': array([0.92442966, 0.96435361, 0.96720532, 0.96768061]),
#  'split22_test_recall': array([0.95413498, 0.94795627, 0.94653042, 0.94249049]),
#  'split23_test_recall': array([0.96910646, 0.96601711, 0.96506654, 0.96269011]),
#  'split24_test_recall': array([0.88735741, 0.90114068, 0.89995247, 0.89519962]),
#  'split25_test_recall': array([0.94272814, 0.94819392, 0.9470057 , 0.94629278]),
#  'split26_test_recall': array([0.99572243, 0.99477186, 0.99429658, 0.99405894]),
#  'split27_test_recall': array([0.9743346 , 0.97409696, 0.97314639, 0.97076996]),
#  'split28_test_recall': array([0.80537072, 0.8381654 , 0.84386882, 0.84339354]),
#  'split29_test_recall': array([0.95413498, 0.94795627, 0.94605513, 0.94391635]),
#  'mean_test_recall': array([0.94317174, 0.95178232, 0.95194867, 0.95060995]),
#  'std_test_recall': array([0.04220097, 0.03204102, 0.03124594, 0.03180963]),
#  'rank_test_recall': array([4, 2, 1, 3], dtype=int32),
#  'split0_train_recall': array([0.92465911, 0.93766389, 0.94111381, 0.94406385]),
#  'split1_train_recall': array([0.93513996, 0.94648125, 0.94675167, 0.94738265]),
#  'split2_train_recall': array([0.93018225, 0.9439983 , 0.94526845, 0.94638292]),
#  'split3_train_recall': array([0.92756818, 0.9424823 , 0.94415399, 0.9455061 ]),
#  'split4_train_recall': array([0.93262423, 0.94558804, 0.94628458, 0.94695654]),
#  'split5_train_recall': array([0.93451718, 0.94614527, 0.94658778, 0.94713682]),
#  'split6_train_recall': array([0.93300118, 0.94576832, 0.94624361, 0.94690737]),
#  'split7_train_recall': array([0.9328209 , 0.94532582, 0.9459568 , 0.9467025 ]),
#  'split8_train_recall': array([0.93300937, 0.94553888, 0.94635014, 0.94739085]),
#  'split9_train_recall': array([0.926634  , 0.94125311, 0.94342468, 0.94503901]),
#  'split10_train_recall': array([0.92677331, 0.94145798, 0.9435394 , 0.94517012]),
#  'split11_train_recall': array([0.93136227, 0.94480136, 0.94608791, 0.94721876]),
#  'split12_train_recall': array([0.92942835, 0.94328537, 0.94460469, 0.94566179]),
#  'split13_train_recall': array([0.93087879, 0.94483414, 0.94593221, 0.94707126]),
#  'split14_train_recall': array([0.92698636, 0.94116297, 0.94322801, 0.94502262]),
#  'split15_train_recall': array([0.9299528 , 0.94376065, 0.9448997 , 0.94609611]),
#  'split16_train_recall': array([0.93087059, 0.94390816, 0.94473581, 0.94577652]),
#  'split17_train_recall': array([0.93020683, 0.9436869 , 0.94501442, 0.94616986]),
#  'split18_train_recall': array([0.92896945, 0.94316245, 0.94470303, 0.94598138]),
#  'split19_train_recall': array([0.92749443, 0.94253147, 0.94458011, 0.94586666]),
#  'split20_train_recall': array([0.92651927, 0.94147437, 0.94340009, 0.94480956]),
#  'split21_train_recall': array([0.92558509, 0.93967976, 0.94237577, 0.944449  ]),
#  'split22_train_recall': array([0.93178838, 0.94501442, 0.94581749, 0.94696473]),
#  'split23_train_recall': array([0.93476301, 0.94585846, 0.94609611, 0.94684181]),
#  'split24_train_recall': array([0.92876459, 0.94381801, 0.94539137, 0.94690737]),
#  'split25_train_recall': array([0.92784679, 0.94256425, 0.9441458 , 0.94554707]),
#  'split26_train_recall': array([0.92968238, 0.94329356, 0.94470303, 0.94591583]),
#  'split27_train_recall': array([0.93298479, 0.9456536 , 0.94621902, 0.94715321]),
#  'split28_train_recall': array([0.92438049, 0.93859807, 0.9427855 , 0.94556346]),
#  'split29_train_recall': array([0.93288646, 0.94554707, 0.94637472, 0.94733349]),
#  'mean_train_recall': array([0.92994269, 0.94347794, 0.94489232, 0.94616631]),
#  'std_train_recall': array([0.00299222, 0.00222232, 0.00138975, 0.00092911])}
# {'svc__C': 2, 'svc__gamma': 0.001, 'svc__kernel': 'rbf'}
# {'accuracy': 0.8675934727503168,
#  'precision': 0.8176541804587018,
#  'recall': 0.9506099493029151}
